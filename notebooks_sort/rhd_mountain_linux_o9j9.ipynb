# %% [markdown]
# ## Notebook for spike sorting from .rhd data using the Pipeline of mountainsort (linux channel has pipeline)
# Uses:
#     - intan2kwik (https://github.com/zekearneodo/intan2kwik/blob/master/README.md)
#     - mountainlab suite(https://github.com/flatironinstitute/mountainlab-js)
#     - mountainsort https://github.com/flatironinstitute/mountainsort_examples/blob/master/README.md
#     - mountainsort examples https://github.com/flatironinstitute/mountainsort_examples/blob/master/README.md

# %%
import os
import glob
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import subprocess
from importlib import reload

# mountainlab imports
from pipefinch.neural.convert import intan
from pipefinch.neural.sort.mountain import core as msc

import logging

# Setup the logger
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

ch = logging.StreamHandler()
ch.setLevel(logging.INFO)
ch.setFormatter(formatter)
logger.addHandler(ch)
        
logger.info('Logger set')
# Out:
# /home/zinch/conda/envs/msort/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/zinch/conda/envs/msort/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/zinch/conda/envs/msort/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 88 from C header, got 96 from PyObject
#   return f(*args, **kwds)
# 2018-12-17 15:27:29,283 - root - INFO - Logger set

# %%
os.environ['OMP_NUM_THREADS'] = '8'
os.environ['MKL_NUM_THREADS'] = '8'
os.environ['NUMEXPR_NUM_THREADS'] = '8'

# %% [markdown]
# ### Session parameters and raw files

# %%
exp_base = os.path.abspath('/home/zinch/data/')
exp_mnt = os.path.abspath('/mnt/zuperfinchjr/Data/')

file_sys = {'exp_base': exp_base}

sess_par = {'bird': 'o9j9',
           'sess': '20181125_r021_saveontrigger',
            'neural': 'Neural'}


def file_names(sess_par, file_sys=None):
    f_s = unroll_file_sys(file_sys_defaults, file_sys)    
    
    f_n = {}
    f_n['raw'] = os.path.join(f_s['raw'], bird)

# %%
exp_base
# Out:
# '/home/zinch/data'

# %%
raw_folder = os.path.join(exp_mnt, sess_par['bird'], sess_par['neural'], sess_par['sess'])
logger.info('Raw folder {}'.format(raw_folder))
#glob.glob(os.path.join(raw_folder, '*.rhd'))
# Out:
# 2018-12-17 15:27:39,000 - root - INFO - Raw folder /mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger

# %%
rhd_files = glob.glob(os.path.join(raw_folder, '*.rhd'))
rhd_files.sort()
pd_f = pd.DataFrame(rhd_files, columns=['f_path'])

pd_f['stamp'] = pd_f['f_path'].apply(lambda x: int(os.path.split(x)[-1].split('.')[0].split('_')[-1]))

# Select some of the files
sess_start = 0
sess_end = 235959
pd_session = pd_f.loc[(pd_f['stamp'] > sess_start) & (pd_f['stamp'] < sess_end), :]
pd_session.index.size

rhd_list = pd_session['f_path'].values.tolist()[:]

# %% [markdown]
# ## Scripts for sorting

# %% [markdown]
# ### prep the files with their nice formats, locations and names

# %%
rhd_list
# Out:
# ['/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_132219.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_132319.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_132419.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_132519.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_132619.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_132719.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_132819.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_132919.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_133019.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_133119.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_133219.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_133319.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_133419.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_135105.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_135115.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_135214.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_135249.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_135329.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_135448.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_135614.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_135847.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_135950.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_140022.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_140117.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_140249.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_140406.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_140524.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_140552.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_140850.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_141050.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_141139.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_141229.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_141329.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_141339.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_141435.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_141517.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_141823.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_142204.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_142242.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_142505.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_142605.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_142638.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_142855.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_143449.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_144454.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_144536.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_144634.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_144731.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_144806.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_144839.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_144931.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_145031.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_145131.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_145352.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_145737.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_145824.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_150418.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_150525.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_150715.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_151509.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_151620.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_152228.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_152803.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_153001.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_153058.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_153718.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_154040.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_154130.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_154305.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_154354.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_154454.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_154459.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_154555.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_154556.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_154650.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_155018.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_155108.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_155115.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_155224.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_155313.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_155413.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_155513.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_155544.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_155713.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_160519.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_164243.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_164737.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_164959.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_165523.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_165612.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_165712.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_165812.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_165912.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_170234.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_170324.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_171403.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_171539.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_172931.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_173053.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_173143.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_173243.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_174655.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_174738.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_174810.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_174841.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_174915.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_174943.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_175047.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_175117.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_175214.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_175229.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_175510.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_175600.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_175700.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_180123.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_180209.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_180349.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_180614.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_180949.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_181039.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_181312.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_182707.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_182758.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_182834.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_182927.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_183009.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_183100.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_183155.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_183255.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_183700.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_184706.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_184758.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_184825.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_184923.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_185023.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_185044.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_185113.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_185146.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_185239.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_185352.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_185441.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_185541.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_185732.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_190038.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_190106.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_190208.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_190336.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_190452.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_190835.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_190925.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_191025.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_191110.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_191248.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_191338.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_191438.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_191645.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_193249.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_193339.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_193439.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_193546.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_193636.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_193736.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_193836.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_193936.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_194036.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_194136.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_194236.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_224336.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_224353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_225353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_230353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_231353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_232353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_233353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_234353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181125_235353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_000353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_001353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_002353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_003353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_004353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_005353.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_013320.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_044905.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_044948.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_052712.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_052754.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_053133.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_053338.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_053430.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_053515.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_054008.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_054129.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_054252.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_054647.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_054848.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_054928.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_054957.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_055025.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_055118.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_055241.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_055421.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_055536.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_055754.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_060010.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_060102.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_060445.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_060610.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_060733.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_060834.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_061033.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_061107.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_061145.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_061419.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_061635.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_061749.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_061824.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_062008.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_062603.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_063002.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_063322.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_063445.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_063642.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_064117.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_065107.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_065323.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_065657.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_070119.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_070356.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_070441.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_070848.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_070918.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_071555.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_071703.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_072653.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_072955.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_073042.rhd',
#  '/mnt/zuperfinchjr/Data/o9j9/Neural/20181125_r021_saveontrigger/o9j9_r020_saveontrigger_181126_073332.rhd']

# %%
f1 = rhd_list[0]
('').join(os.path.split(f1)[-1].split('_')[-2:]).split('.')[0]
# Out:
# '181125132219'

# %%
ss_folder = os.path.join(exp_base, sess_par['bird'], 'ss_data', sess_par['sess'])

file_paths, out_folder = msc.make_paths(ss_folder)
os.makedirs(ss_folder, exist_ok=True)
#todo:
# meta and pars from intan files et al
s_f = 20000

# parameters to pass to the msort scripts
ds_params = {'samplerate': s_f,
            'detect_sign': -1}

with open(file_paths['params'], 'w') as fp:
    json.dump(ds_params, fp)
    logger.info('Created session par files {}'.format(file_paths['params']))
    
# create the mda file from the rhd_list
#intan_meta, samples_in = intan.intan_to_bin(rhd_list[:], file_paths['mda'], variant='mda');
# Out:
# 2018-12-17 15:29:21,156 - root - INFO - Created session par files /home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/params.json

# %%
ds_params
# Out:
# {'samplerate': 20000, 'detect_sign': -1}

# %%
file_paths
# Out:
# {'mda': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/raw.mda',
#  'params': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/params.json',
#  'geom': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/geom.csv',
#  'filt': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/filt.mda.prv',
#  'pre': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/pre.mda.prv',
#  'firings': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda',
#  'firings_curated': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings_curated.mda',
#  'cluster_metrics': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/cluster_metrics.json'}

# %%
# test mountainsort method for reading sorting parameters
msc.read_dataset_params(ss_folder)
# Out:
# {'samplerate': 20000, 'detect_sign': -1}

# %%
# Initialize a pipeline
from mountainlab_pytools import mlproc as mlp
Pipeline=mlp.initPipeline();
# Out:
# JSProxyWidget(status='Not yet rendered')

# %%
msc.sort_dataset?
# Out:
# Signature: msc.sort_dataset(*, file_paths:dict, freq_min:int=300, freq_max:int=6000, adjacency_radius:int=1, detect_threshold:float=3, dispatch_method:str='run', opts:dict={})
# Docstring: <no docstring>
# File:      ~/repos/pipefinch/pipefinch/neural/sort/mountain/core.py
# Type:      function

# %%
output_dir = os.path.join(ss_folder, 'sort_out');
# Pipeline was failing, need to debug this ('NameError: name 'widgets' is not defined')
# with Pipeline:
#     msc.sort_dataset(file_paths=file_paths, adjacency_radius=-1, detect_threshold=3, dispatch_method='add')

msc.sort_dataset(file_paths=file_paths, adjacency_radius=-1, detect_threshold=2, freq_min=600);
# Out:
# 2018-12-06 15:34:24,142 - pipefinch.sort.mountain.comre - INFO - Bandpass filter
# RUNNING: ml-run-process ephys.bandpass_filter --inputs timeseries:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/raw.mda --parameters freq_max:6000 freq_min:600 samplerate:20000 --outputs timeseries_out:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/filt.mda.prv
# 2018-12-06 15:38:36,371 - pipefinch.sort.mountain.comre - INFO - Whitening
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: 8f2427a3a5e7d84a7319c5bcb67b7f5ee02a605d
# [ Checking outputs... ]
# {"timeseries_out":"/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/filt.mda.prv"}
# Processing ouput - /home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/filt.mda.prv
# false
# {"timeseries_out":"/tmp/mountainlab-tmp/output_8f2427a3a5e7d84a7319c5bcb67b7f5ee02a605d_timeseries_out.mda"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /tmp/mountainlab-tmp/output_8f2427a3a5e7d84a7319c5bcb67b7f5ee02a605d_timeseries_out.mda
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ephys/preprocessing/preprocessing.py.mp ephys.bandpass_filter --_tempdir=/tmp/mountainlab-tmp/tempdir_8f2427a3a5_Ichjji --timeseries=/tmp/mountainlab-tmp/tempdir_8f2427a3a5_Ichjji/input_timeseries_6JiyQTtK.mda --timeseries_out=/tmp/mountainlab-tmp/tempdir_8f2427a3a5_Ichjji/output_timeseries_out.mda --freq_max=6000 --freq_min=600 --samplerate=20000
# Chunk size: 30000, Padding: 3000, Num chunks: 14204, Num processes: 8
#
# Processed 2020 of 14204 chunks...
# Processed 7813 of 14204 chunks...
# Processed 12760 of 14204 chunks...
# Processed 13053 of 14204 chunks...
# Processed 1164 of 14204 chunks...
# Processed 1734 of 14204 chunks...
# Processed 4083 of 14204 chunks...
# Processed 4915 of 14204 chunks...
# Processed 5486 of 14204 chunks...
# Processed 8977 of 14204 chunks...
# Processed 10717 of 14204 chunks...
# Processed 11865 of 14204 chunks...
# Processed 12149 of 14204 chunks...
# Processed 1452 of 14204 chunks...
# Processed 4361 of 14204 chunks...
# Processed 7218 of 14204 chunks...
# Processed 8402 of 14204 chunks...
# Processed 8697 of 14204 chunks...
# Processed 9254 of 14204 chunks...
# Processed 9549 of 14204 chunks...
# Processed 9843 of 14204 chunks...
# Processed 12451 of 14204 chunks...
# Processed 13631 of 14204 chunks...
# Processed 3204 of 14204 chunks...
# Processed 7514 of 14204 chunks...
# Processed 13924 of 14204 chunks...
# Processed 289 of 14204 chunks...
# Processed 2914 of 14204 chunks...
# Processed 6923 of 14204 chunks...
# Processed 11578 of 14204 chunks...
# Processed 2624 of 14204 chunks...
# Processed 3516 of 14204 chunks...
# Processed 6359 of 14204 chunks...
# Processed 6649 of 14204 chunks...
# Processed 11018 of 14204 chunks...
# Processed 11306 of 14204 chunks...
# Processed 592 of 14204 chunks...
# Processed 3811 of 14204 chunks...
# Processed 4635 of 14204 chunks...
# Processed 8110 of 14204 chunks...
# Processed 10436 of 14204 chunks...
# Processed 873 of 14204 chunks...
# Processed 2314 of 14204 chunks...
# Processed 5203 of 14204 chunks...
# Processed 5765 of 14204 chunks...
# Processed 6062 of 14204 chunks...
# Processed 10144 of 14204 chunks...
# Processed 13337 of 14204 chunks...
#
# Elapsed time for processor ephys.bandpass_filter: 197.096 sec
# Finalizing output timeseries_out
# [ Creating output prv for timeseries_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ephys.whiten --inputs timeseries:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/filt.mda.prv --parameters --outputs timeseries_out:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/pre.mda.prv
# 2018-12-06 15:40:17,958 - pipefinch.sort.mountain.comre - INFO - Sorting
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: ddf025a74c7f2fbad77f642fd7b312237bd073a2
# [ Checking outputs... ]
# {"timeseries_out":"/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/pre.mda.prv"}
# Processing ouput - /home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/pre.mda.prv
# false
# {"timeseries_out":"/tmp/mountainlab-tmp/output_ddf025a74c7f2fbad77f642fd7b312237bd073a2_timeseries_out.mda"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /tmp/mountainlab-tmp/output_ddf025a74c7f2fbad77f642fd7b312237bd073a2_timeseries_out.mda
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ephys/preprocessing/preprocessing.py.mp ephys.whiten --_tempdir=/tmp/mountainlab-tmp/tempdir_ddf025a74c_RbP2yL --timeseries=/tmp/mountainlab-tmp/tempdir_ddf025a74c_RbP2yL/input_timeseries_oi3TOXFP.mda --timeseries_out=/tmp/mountainlab-tmp/tempdir_ddf025a74c_RbP2yL/output_timeseries_out.mda
# Chunk size: 300000, Num chunks: 1421, Num processes: 8
#
# Processed 1004 of 1421 chunks...
# Processed 1403 of 1421 chunks...
#
# Processed 1140 of 1421 chunks...
# Processed 1268 of 1421 chunks...
# Processed 263 of 1421 chunks...
# Processed 760 of 1421 chunks...
#
# Processed 125 of 1421 chunks...
# Processed 881 of 1421 chunks...
# Processed 521 of 1421 chunks...
#
# Processed 634 of 1421 chunks...
# Processed 396 of 1421 chunks...
#
# Elapsed time for processor ephys.whiten: 45.795 sec
# Finalizing output timeseries_out
# [ Creating output prv for timeseries_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# /home/zinch/repos/pipefinch/pipefinch/neural/sort/mountain/core.py:168: UserWarning: Will sort with no geometry input
#   warnings.warn('Will sort with no geometry input')
# RUNNING: ml-run-process ms4alg.sort --inputs timeseries:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/pre.mda.prv --parameters adjacency_radius:-1 detect_sign:-1 detect_threshold:2 --outputs firings_out:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda
# [ Getting processor spec... ]
# /home/zinch/conda/envs/msort/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 88 from C header, got 96 from PyObject
# [ Checking inputs and substituting prvs ... ]
# return f(*args, **kwds)
# [ Computing process signature ... ]
# 2018-12-06 16:06:08,588 - pipefinch.sort.mountain.comre - INFO - Getting cluster metrics
# Process signature: 5d78541c7eb38312b7b3efa04a70139d1323169a
# [ Checking outputs... ]
# {"firings_out":"/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda"}
# Processing ouput - /home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda
# false
# {"firings_out":"/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ms4alg/ms4alg_spec.py.mp ms4alg.sort --_tempdir=/tmp/mountainlab-tmp/tempdir_5d78541c7e_cWoI4S --timeseries=/tmp/mountainlab-tmp/tempdir_5d78541c7e_cWoI4S/input_timeseries_2PQcRCuD.mda --geom= --firings_out=/tmp/mountainlab-tmp/tempdir_5d78541c7e_cWoI4S/output_firings_out.mda --adjacency_radius=-1 --detect_sign=-1 --detect_threshold=2
# Using tempdir=/tmp/mountainlab-tmp/tempdir_5d78541c7e_cWoI4S
# Preparing /tmp/mountainlab-tmp/tempdir_5d78541c7e_cWoI4S/timeseries.hdf5...
# Preparing neighborhood sorters (M=13, N=426098160)...
#
# Detecting events on channel 1 (phase1)...
#
# Detecting events on channel 3 (phase1)...
#
# Detecting events on channel 7 (phase1)...
#
# Detecting events on channel 5 (phase1)...
#
# Detecting events on channel 6 (phase1)...
# Detecting events on channel 2 (phase1)...
#
# Detecting events on channel 8 (phase1)...
#
# Detecting events on channel 4 (phase1)...
#
# Num events detected on channel 1 (phase1): 170044
# Computing PCA features for channel 1 (phase1)...
#
# Num events detected on channel 2 (phase1): 152634
#
# Computing PCA features for channel 2 (phase1)...
#
# Num events detected on channel 6 (phase1): 108987
# Computing PCA features for channel 6 (phase1)...
#
# Num events detected on channel 8 (phase1): 111448
#
# Computing PCA features for channel 8 (phase1)...
#
# Num events detected on channel 7 (phase1): 173920
#
# Computing PCA features for channel 7 (phase1)...
#
# Num events detected on channel 4 (phase1): 119429
#
# Computing PCA features for channel 4 (phase1)...
#
# Num events detected on channel 5 (phase1): 134954
# Computing PCA features for channel 5 (phase1)...
#
# Num events detected on channel 3 (phase1): 203811
#
# Computing PCA features for channel 3 (phase1)...
#
# Clustering for channel 4 (phase1)...
#
# Clustering for channel 6 (phase1)...
#
# Clustering for channel 2 (phase1)...
#
# Found 1 clusters for channel 4 (phase1)...
#
# Computing templates for channel 4 (phase1)...
#
# Clustering for channel 8 (phase1)...
#
# Found 1 clusters for channel 6 (phase1)...
#
# Computing templates for channel 6 (phase1)...
#
# Clustering for channel 3 (phase1)...
#
# Clustering for channel 5 (phase1)...
#
# Clustering for channel 1 (phase1)...
#
# Found 1 clusters for channel 5 (phase1)...
#
# Computing templates for channel 5 (phase1)...
#
# Found 3 clusters for channel 8 (phase1)...
#
# Computing templates for channel 8 (phase1)...
#
# Found 1 clusters for channel 3 (phase1)...
# Computing templates for channel 3 (phase1)...
#
# Found 3 clusters for channel 2 (phase1)...
#
# Computing templates for channel 2 (phase1)...
#
# Found 2 clusters for channel 1 (phase1)...
# Computing templates for channel 1 (phase1)...
#
# Clustering for channel 7 (phase1)...
#
# Found 3 clusters for channel 7 (phase1)...
#
# Computing templates for channel 7 (phase1)...
#
# Re-assigning events for channel 4 (phase1)...
#
# Detecting events on channel 9 (phase1)...
#
# Re-assigning events for channel 6 (phase1)...
#
# Detecting events on channel 10 (phase1)...
#
# Re-assigning events for channel 5 (phase1)...
#
# Detecting events on channel 11 (phase1)...
#
# Re-assigning events for channel 8 (phase1)...
#
# Detecting events on channel 12 (phase1)...
#
# Re-assigning events for channel 2 (phase1)...
#
# Detecting events on channel 13 (phase1)...
#
# Re-assigning events for channel 3 (phase1)...
#
# Re-assigning events for channel 1 (phase1)...
#
# Re-assigning events for channel 7 (phase1)...
#
# Re-assigning 254 events from 7 to 2 with dt=-3 (k=1)
#
# Num events detected on channel 9 (phase1): 1325265
#
# Computing PCA features for channel 9 (phase1)...
#
# Num events detected on channel 10 (phase1): 335970
# Computing PCA features for channel 10 (phase1)...
#
# Num events detected on channel 12 (phase1): 100771
#
# Computing PCA features for channel 12 (phase1)...
#
# Num events detected on channel 11 (phase1): 149732
# Computing PCA features for channel 11 (phase1)...
#
# Num events detected on channel 13 (phase1): 155995
#
# Computing PCA features for channel 13 (phase1)...
#
# Clustering for channel 12 (phase1)...
#
# Found 2 clusters for channel 12 (phase1)...
#
# Computing templates for channel 12 (phase1)...
#
# Clustering for channel 11 (phase1)...
#
# Clustering for channel 10 (phase1)...
#
# Found 2 clusters for channel 11 (phase1)...
#
# Computing templates for channel 11 (phase1)...
#
# Clustering for channel 9 (phase1)...
#
# Clustering for channel 13 (phase1)...
#
# Found 2 clusters for channel 10 (phase1)...
# Computing templates for channel 10 (phase1)...
#
# Found 2 clusters for channel 13 (phase1)...
# Computing templates for channel 13 (phase1)...
#
# Re-assigning events for channel 12 (phase1)...
#
# Re-assigning events for channel 11 (phase1)...
#
# Re-assigning events for channel 10 (phase1)...
#
# Re-assigning events for channel 13 (phase1)...
#
# Found 1 clusters for channel 9 (phase1)...
# Computing templates for channel 9 (phase1)...
#
# Re-assigning events for channel 9 (phase1)...
#
# Computing PCA features for channel 4 (phase2)...
#
# Computing PCA features for channel 2 (phase2)...
#
# Computing PCA features for channel 5 (phase2)...
#
# Computing PCA features for channel 6 (phase2)...
#
# Computing PCA features for channel 3 (phase2)...
#
# Computing PCA features for channel 7 (phase2)...
#
# Computing PCA features for channel 1 (phase2)...
#
# Computing PCA features for channel 8 (phase2)...
#
# Clustering for channel 2 (phase2)...
#
# Clustering for channel 8 (phase2)...
#
# Clustering for channel 6 (phase2)...
#
# Found 5 clusters for channel 8 (phase2)...
#
# Computing PCA features for channel 9 (phase2)...
#
# Found 7 clusters for channel 2 (phase2)...
#
# Computing PCA features for channel 10 (phase2)...
#
# Found 8 clusters for channel 6 (phase2)...
#
# Computing PCA features for channel 11 (phase2)...
#
# Clustering for channel 5 (phase2)...
#
# Found 6 clusters for channel 5 (phase2)...
#
# Computing PCA features for channel 12 (phase2)...
#
# Clustering for channel 3 (phase2)...
#
# Clustering for channel 1 (phase2)...
#
# Found 5 clusters for channel 1 (phase2)...
#
# Computing PCA features for channel 13 (phase2)...
#
# Clustering for channel 4 (phase2)...
#
# Found 6 clusters for channel 3 (phase2)...
#
# Found 15 clusters for channel 4 (phase2)...
#
# Clustering for channel 7 (phase2)...
#
# Found 3 clusters for channel 7 (phase2)...
#
# Clustering for channel 12 (phase2)...
#
# Found 17 clusters for channel 12 (phase2)...
#
# Clustering for channel 13 (phase2)...
#
# Clustering for channel 11 (phase2)...
#
# Found 8 clusters for channel 13 (phase2)...
#
# Found 2 clusters for channel 11 (phase2)...
#
# Clustering for channel 10 (phase2)...
#
# Found 5 clusters for channel 10 (phase2)...
#
# Clustering for channel 9 (phase2)...
#
# Found 2 clusters for channel 9 (phase2)...
#
# Preparing output...
#
# Writing firings file...
#
# Done.
#
# Elapsed time for processor ms4alg.sort: 1518.875 sec
# Finalizing output firings_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.cluster_metrics --inputs firings:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda timeseries:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/pre.mda.prv --parameters samplerate:20000 --outputs cluster_metrics_out:/tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_cluster_metrics_out_144e772aacd57d0ec86d7509f7fd91d777a3a519.prv
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: 8a9ba78ef6c313fbcaf5dc1912a71203967921be
# [ Checking outputs... ]
# {"cluster_metrics_out":"/tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_cluster_metrics_out_144e772aacd57d0ec86d7509f7fd91d777a3a519.prv"}
# Processing ouput - /tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_cluster_metrics_out_144e772aacd57d0ec86d7509f7fd91d777a3a519.prv
# false
# {"cluster_metrics_out":"/tmp/mountainlab-tmp/output_8a9ba78ef6c313fbcaf5dc1912a71203967921be_cluster_metrics_out.output_cluster_metrics_out_144e772aacd57d0ec86d7509f7fd91d777a3a519"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /tmp/mountainlab-tmp/output_8a9ba78ef6c313fbcaf5dc1912a71203967921be_cluster_metrics_out.output_cluster_metrics_out_144e772aacd57d0ec86d7509f7fd91d777a3a519
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/etc/mountainlab/packages/ms3.mp ms3.cluster_metrics --_tempdir=/tmp/mountainlab-tmp/tempdir_8a9ba78ef6_A4qpTi --firings=/tmp/mountainlab-tmp/tempdir_8a9ba78ef6_A4qpTi/input_firings_33CmWDni.mda --timeseries=/tmp/mountainlab-tmp/tempdir_8a9ba78ef6_A4qpTi/input_timeseries_l7QhHRwt.mda --cluster_metrics_out=/tmp/mountainlab-tmp/tempdir_8a9ba78ef6_A4qpTi/output_cluster_metrics_out.output_cluster_metrics_out_144e772aacd57d0ec86d7509f7fd91d777a3a519 --samplerate=20000
# Elapsed time for processor ms3.cluster_metrics: 0.172 sec
# Finalizing output cluster_metrics_out
# [ Creating output prv for cluster_metrics_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.isolation_metrics --inputs firings:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda timeseries:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/pre.mda.prv --parameters compute_bursting_parents:true --outputs metrics_out:/tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_metrics_out_26121392ef022c03281c93a5ecf2cba0db4c7942.prv
# [ Getting processor spec... ]
# Starting p_isolation_metrics
# [ Checking inputs and substituting prvs ... ]
#
# [ Computing process signature ... ]
# Computing cluster metrics...
# Process signature: c5335dee9b6afc583409a2425d6c70df6ba806b2
#
# [ Checking outputs... ]
# Computing templates...
# {"metrics_out":"/tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_metrics_out_26121392ef022c03281c93a5ecf2cba0db4c7942.prv"}
#
# Processing ouput - /tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_metrics_out_26121392ef022c03281c93a5ecf2cba0db4c7942.prv
# Determining pairs to compare...
# false
#
# {"metrics_out":"/tmp/mountainlab-tmp/output_c5335dee9b6afc583409a2425d6c70df6ba806b2_metrics_out.output_metrics_out_26121392ef022c03281c93a5ecf2cba0db4c7942"}
# Computing bursting parents...
# [ Checking process cache ... ]
#
# [ Creating temporary directory ... ]
# preparing clusters array
# [ Creating links to input files... ]
#
# [ Preparing temporary outputs... ]
# Writing output...
# Processing ouput - /tmp/mountainlab-tmp/output_c5335dee9b6afc583409a2425d6c70df6ba806b2_metrics_out.output_metrics_out_26121392ef022c03281c93a5ecf2cba0db4c7942
#
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/etc/mountainlab/packages/ms3.mp ms3.isolation_metrics --_tempdir=/tmp/mountainlab-tmp/tempdir_c5335dee9b_nYvXQY --firings=/tmp/mountainlab-tmp/tempdir_c5335dee9b_nYvXQY/input_firings_TPSduCbf.mda --timeseries=/tmp/mountainlab-tmp/tempdir_c5335dee9b_nYvXQY/input_timeseries_ijmIdEsH.mda --metrics_out=/tmp/mountainlab-tmp/tempdir_c5335dee9b_nYvXQY/output_metrics_out.output_metrics_out_26121392ef022c03281c93a5ecf2cba0db4c7942 --pair_metrics_out= --compute_bursting_parents=true
# Elapsed time for processor ms3.isolation_metrics: 22.877 sec
# Finalizing output metrics_out
# [ Creating output prv for metrics_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.combine_cluster_metrics --inputs metrics_list:/tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_cluster_metrics_out_144e772aacd57d0ec86d7509f7fd91d777a3a519.prv metrics_list:/tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_metrics_out_26121392ef022c03281c93a5ecf2cba0db4c7942.prv --parameters --outputs metrics_out:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/cluster_metrics.json
# 2018-12-06 16:08:25,247 - pipefinch.sort.mountain.comre - INFO - Automatically curating
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: db2879f75f6042453a0d5822eafc62f0ab3d6d31
# [ Checking outputs... ]
# {"metrics_out":"/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/cluster_metrics.json"}
# Processing ouput - /home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/cluster_metrics.json
# false
# {"metrics_out":"/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/cluster_metrics.json"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/cluster_metrics.json
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/etc/mountainlab/packages/ms3.mp ms3.combine_cluster_metrics --_tempdir=/tmp/mountainlab-tmp/tempdir_db2879f75f_vTkHuD --metrics_list=/tmp/mountainlab-tmp/tempdir_db2879f75f_vTkHuD/input_metrics_list-0_ezIJSWgP.output_cluster_metrics_out_144e772aacd57d0ec86d7509f7fd91d777a3a519 --metrics_list=/tmp/mountainlab-tmp/tempdir_db2879f75f_vTkHuD/input_metrics_list-1_ZoclSmzn.output_metrics_out_26121392ef022c03281c93a5ecf2cba0db4c7942 --metrics_out=/tmp/mountainlab-tmp/tempdir_db2879f75f_vTkHuD/output_metrics_out.json
# Elapsed time for processor ms3.combine_cluster_metrics: 0.017 sec
# Finalizing output metrics_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms4alg.create_label_map --inputs metrics:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/cluster_metrics.json --parameters --outputs label_map_out:/tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_label_map_out_6a18ed3cb44bc95da92030a797b1bd7c60bd5f4a.prv
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: 528af96f9777fbaf1aa2906386c0b31915207e87
# [ Checking outputs... ]
# {"label_map_out":"/tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_label_map_out_6a18ed3cb44bc95da92030a797b1bd7c60bd5f4a.prv"}
# Processing ouput - /tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_label_map_out_6a18ed3cb44bc95da92030a797b1bd7c60bd5f4a.prv
# false
# {"label_map_out":"/tmp/mountainlab-tmp/output_528af96f9777fbaf1aa2906386c0b31915207e87_label_map_out.output_label_map_out_6a18ed3cb44bc95da92030a797b1bd7c60bd5f4a"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /tmp/mountainlab-tmp/output_528af96f9777fbaf1aa2906386c0b31915207e87_label_map_out.output_label_map_out_6a18ed3cb44bc95da92030a797b1bd7c60bd5f4a
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ms4alg/curation_spec.py.mp ms4alg.create_label_map --_tempdir=/tmp/mountainlab-tmp/tempdir_528af96f97_illZwq --metrics=/tmp/mountainlab-tmp/tempdir_528af96f97_illZwq/input_metrics_mIde1TN5.json --label_map_out=/tmp/mountainlab-tmp/tempdir_528af96f97_illZwq/output_label_map_out.output_label_map_out_6a18ed3cb44bc95da92030a797b1bd7c60bd5f4a
# Elapsed time for processor ms4alg.create_label_map: 0.344 sec
# Finalizing output label_map_out
# [ Creating output prv for label_map_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms4alg.apply_label_map --inputs firings:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda label_map:/tmp/mountainlab-tmp/mountainlab/tmp_short_term/output_label_map_out_6a18ed3cb44bc95da92030a797b1bd7c60bd5f4a.prv --parameters --outputs firings_out:/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings_curated.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: 3a0f1f2687734089dfa120ba514656a835be0518
# [ Checking outputs... ]
# {"firings_out":"/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings_curated.mda"}
# Processing ouput - /home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings_curated.mda
# false
# {"firings_out":"/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings_curated.mda"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings_curated.mda
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ms4alg/curation_spec.py.mp ms4alg.apply_label_map --_tempdir=/tmp/mountainlab-tmp/tempdir_3a0f1f2687_y0K9XS --firings=/tmp/mountainlab-tmp/tempdir_3a0f1f2687_y0K9XS/input_firings_xiCzeXGb.mda --label_map=/tmp/mountainlab-tmp/tempdir_3a0f1f2687_y0K9XS/input_label_map_rklYO1fW.output_label_map_out_6a18ed3cb44bc95da92030a797b1bd7c60bd5f4a --firings_out=/tmp/mountainlab-tmp/tempdir_3a0f1f2687_y0K9XS/output_firings_out.mda
# Elapsed time for processor ms4alg.apply_label_map: 0.646 sec
# Finalizing output firings_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]

# %%
file_paths
# Out:
# {'mda': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/raw.mda',
#  'params': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/params.json',
#  'geom': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/geom.csv',
#  'filt': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/filt.mda.prv',
#  'pre': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/pre.mda.prv',
#  'firings': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings.mda',
#  'firings_curated': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/firings_curated.mda',
#  'cluster_metrics': '/home/zinch/data/o9j9/ss_data/20181125_r021_saveontrigger/sort_out/cluster_metrics.json'}

# %% [markdown]
# ## Command for viewing:
#  - open up terminal with the environment msort
#  - go go the ss_data folder for the session
#  - run the command: qt-mountainview --raw raw.mda --filt sort_out/filt.mda.prv --pre sort_out/pre.mda.prv --samplerate=20000 --firings sort_out/firings.mda --cluster_metrics sort_out/cluster_metrics.json
