# %% [markdown]
# ## Notebook for spike sorting from .kwd data using the Pipeline of mountainsort (linux channel has pipeline)
# Uses:
#     - intan2kwik (https://github.com/zekearneodo/intan2kwik/blob/master/README.md)
#     - mountainlab suite(https://github.com/flatironinstitute/mountainlab-js)
#     - mountainsort https://github.com/flatironinstitute/mountainsort_examples/blob/master/README.md
#     - mountainsort examples https://github.com/flatironinstitute/mountainsort_examples/blob/master/README.md

# %%
import socket
import os
import glob
import json
from typing import Union
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import subprocess
from datetime import timedelta
from importlib import reload

# pipeline imports
from pipefinch.neural.convert import intan
from pipefinch.neural.sort.mountain import core as msc
from pipefinch.h5tools.kwik import kutil
from pipefinch.pipeline import probes


from pipefinch.h5tools.kwik import kwdfunctions as kwdf

from intan2kwik import kwd

#mountainsort imports (for sorting)
#import mountainlab_pytools.mlproc as mlp

import logging

# Setup the logger
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

ch = logging.StreamHandler()
ch.setLevel(logging.INFO)
ch.setFormatter(formatter)
logger.addHandler(ch)
        
logger.info('Logger set')
logger.info('Hostname {}'.format(socket.gethostname()))
# Out:
# 2019-04-23 15:39:38,179 - root - INFO - Logger set
# 2019-04-23 15:39:38,179 - root - INFO - Hostname lookfar

# %% [markdown]
# ### Session parameters and raw files

# %%
from pipefinch.neural.sort import kilo

# %%
from pipefinch.pipeline import filestructure as et
reload(et)
reload(kwd)

# sess_par = {'bird': 'p14r14',
#            'sess': '2019-02-14_2250_01'}
sess_par = {'bird': 'p14r14',
           'sess': '2019-02-15_3125_01',
           'probe': 'probe_0' # probe to sort ('probe_0', 'probe_1') (to lookup in the rig_par which port to extract)
           }

exp_struct = et.get_exp_struct(sess_par['bird'], sess_par['sess'])

sort_params = {'adjacency_radius': -1,
              'detect_threshold': 2,
              'freq_min': 600}

ds_params = {'detect_sign': -1}

ks_params = {'use_gpu': 1,
            'auto_merge': 1,
            'filt_per_chan': 4,
            }

# convenient paths
kwik_folder = exp_struct['folders']['kwik']
msort_folder = exp_struct['folders']['msort']
raw_folder = exp_struct['folders']['raw']
kwd_path = exp_struct['files']['kwd']
bin_path = exp_struct['files']['mda_raw']

# %%
exp_struct
# Out:
# {'folders': {'raw': '/Volumes/Samsung_X5/microdrive/p14r14/Ephys/raw/2019-02-15_3125_01',
#   'kwik': '/Volumes/Samsung_X5/microdrive/p14r14/Ephys/kwik/2019-02-15_3125_01',
#   'msort': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/msort/2019-02-15_3125_01',
#   'ksort': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01'},
#  'files': {'par': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/params.json',
#   'set': '/Volumes/Samsung_X5/microdrive/p14r14/Ephys/raw/2019-02-15_3125_01/settings.isf',
#   'rig': '/Volumes/Samsung_X5/microdrive/p14r14/Ephys/raw/2019-02-15_3125_01/rig.json',
#   'kwd': '/Volumes/Samsung_X5/microdrive/p14r14/Ephys/kwik/2019-02-15_3125_01/streams.kwd',
#   'kwik': '/Volumes/Samsung_X5/microdrive/p14r14/Ephys/kwik/2019-02-15_3125_01/spikes.kwik',
#   'kwe': '/Volumes/Samsung_X5/microdrive/p14r14/Ephys/kwik/2019-02-15_3125_01/events.kwe',
#   'mda_raw': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/msort/2019-02-15_3125_01/raw.mda',
#   'bin_raw': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/raw.bin'}}

# %% [markdown]
# ### convert the whole session to a .kwd file
# Conversion sends every .rhd file in the folder to a rec in the .kwd file (experiment.kwd in the session ss folder)
# All of the files and all of the channels are converted; filtering and subselection of sub-epochs and channels occurs later.
# The .kwd is raw data, only in a friendlier format.

# %% [markdown]
# #### Make a file for the session for the first time

# %%
reload(kwd)
## Convert the whole session to a kwd file
os.makedirs(kwik_folder, exist_ok=True)
first_intan_hdr, sess_pd = kwd.intan_to_kwd(raw_folder, kwd_path)
# Out:
# 2019-04-23 15:39:55,485 - intan2kwik.kwd - INFO - reading intan chans data across all of rec /Volumes/Samsung_X5/microdrive/p14r14/Ephys/raw/2019-02-15_3125_01
# 2019-04-23 15:39:55,504 - intan2kwik.kwd - INFO - Found 5 .rhd files split in 5 recordings
# 2019-04-23 15:39:55,505 - intan2kwik.kwd - INFO - dest file: /Volumes/Samsung_X5/microdrive/p14r14/Ephys/kwik/2019-02-15_3125_01/streams.kwd
# HBox(children=(IntProgress(value=0, description='Sess', max=5, style=ProgressStyle(description_width='initial'…
# HBox(children=(IntProgress(value=0, description='rec 0', max=1, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='raw_190215_102323.rhd', max=58068, style=ProgressStyle(descri…
# HBox(children=(IntProgress(value=0, description='notch filter', max=32, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='rec 1', max=1, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='raw_190215_102738.rhd', max=33288, style=ProgressStyle(descri…
# HBox(children=(IntProgress(value=0, description='notch filter', max=32, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='rec 2', max=1, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='raw_190215_103028.rhd', max=77628, style=ProgressStyle(descri…
# HBox(children=(IntProgress(value=0, description='notch filter', max=32, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='rec 3', max=1, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='raw_190215_103455.rhd', max=59436, style=ProgressStyle(descri…
# HBox(children=(IntProgress(value=0, description='notch filter', max=32, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='rec 4', max=1, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='raw_190215_103745.rhd', max=88320, style=ProgressStyle(descri…
# HBox(children=(IntProgress(value=0, description='notch filter', max=32, style=ProgressStyle(description_width=…
# 2019-04-23 15:40:55,875 - intan2kwik.kwd - INFO - moving back to /Volumes/Samsung_X5/microdrive/p14r14/Ephys/kwik/2019-02-15_3125_01/streams.kwd
# 2019-04-23 15:40:56,890 - intan2kwik.kwd - INFO - removing temp file

# %% [markdown]
# # play with glxtokwik

# %%
from intan2kwik.core.file import util as fu
import datetime
import time
reload(fu)
# Out:
# <module 'intan2kwik.core.file.util' from '/Users/zeke/repos/intan2kwik/intan2kwik/core/file/util.py'>

# %%
sess_pd
# Out:
#                                                 path                 f_name  \
# 0  /Volumes/Samsung_X5/microdrive/p14r14/Ephys/ra...  raw_190215_102323.rhd
# 1  /Volumes/Samsung_X5/microdrive/p14r14/Ephys/ra...  raw_190215_102738.rhd
# 2  /Volumes/Samsung_X5/microdrive/p14r14/Ephys/ra...  raw_190215_103028.rhd
# 3  /Volumes/Samsung_X5/microdrive/p14r14/Ephys/ra...  raw_190215_103455.rhd
# 4  /Volumes/Samsung_X5/microdrive/p14r14/Ephys/ra...  raw_190215_103745.rhd
#
#               t_stamp   t_diff  rec_break  rec
# 0 2019-02-15 10:23:23      NaT      False    0
# 1 2019-02-15 10:27:38 00:04:15       True    1
# 2 2019-02-15 10:30:28 00:02:50       True    2
# 3 2019-02-15 10:34:55 00:04:27       True    3
# 4 2019-02-15 10:37:45 00:02:50       True    4

# %%
def read_chan_order(meta_parse) -> pd.DataFrame:
    # meta_parse is the ini parameter file, read with read_headless_config
    # we want a three col array with [ch_name, order_in_group, order_in_total]
    chans = meta_parse.get('root', '~snsChanMap')
    chans_tuple_list = lf_chans.split(')(')[1:]
    chans_tuple_list[-1]=chans_tuple_list[-1].split(')')[0]
    all_tuples = [parse.parse('{};{}:{}', x).fixed for x in chans_tuple_list]
    return pd.DataFrame(atp, columns=['name', 'order', 'abs_order'])


atp = read_chan_order(cp)

# %%
atp.head(5)
# Out:
#   name order abs_order
# 0  LF0   384       384
# 1  LF1   385       385
# 2  LF2   386       386
# 3  LF3   387       387
# 4  LF4   388       388

# %%
atp['name'].values
# Out:
# array(['LF0', 'LF1', 'LF2', 'LF3', 'LF4', 'LF5', 'LF6', 'LF7', 'LF8',
#        'LF9', 'LF10', 'LF11', 'LF12', 'LF13', 'LF14', 'LF15', 'LF16',
#        'LF17', 'LF18', 'LF19', 'LF20', 'LF21', 'LF22', 'LF23', 'LF24',
#        'LF25', 'LF26', 'LF27', 'LF28', 'LF29', 'LF30', 'LF31', 'LF32',
#        'LF33', 'LF34', 'LF35', 'LF36', 'LF37', 'LF38', 'LF39', 'LF40',
#        'LF41', 'LF42', 'LF43', 'LF44', 'LF45', 'LF46', 'LF47', 'LF48',
#        'LF49', 'LF50', 'LF51', 'LF52', 'LF53', 'LF54', 'LF55', 'LF56',
#        'LF57', 'LF58', 'LF59', 'LF60', 'LF61', 'LF62', 'LF63', 'LF64',
#        'LF65', 'LF66', 'LF67', 'LF68', 'LF69', 'LF70', 'LF71', 'LF72',
#        'LF73', 'LF74', 'LF75', 'LF76', 'LF77', 'LF78', 'LF79', 'LF80',
#        'LF81', 'LF82', 'LF83', 'LF84', 'LF85', 'LF86', 'LF87', 'LF88',
#        'LF89', 'LF90', 'LF91', 'LF92', 'LF93', 'LF94', 'LF95', 'LF96',
#        'LF97', 'LF98', 'LF99', 'LF100', 'LF101', 'LF102', 'LF103',
#        'LF104', 'LF105', 'LF106', 'LF107', 'LF108', 'LF109', 'LF110',
#        'LF111', 'LF112', 'LF113', 'LF114', 'LF115', 'LF116', 'LF117',
#        'LF118', 'LF119', 'LF120', 'LF121', 'LF122', 'LF123', 'LF124',
#        'LF125', 'LF126', 'LF127', 'LF128', 'LF129', 'LF130', 'LF131',
#        'LF132', 'LF133', 'LF134', 'LF135', 'LF136', 'LF137', 'LF138',
#        'LF139', 'LF140', 'LF141', 'LF142', 'LF143', 'LF144', 'LF145',
#        'LF146', 'LF147', 'LF148', 'LF149', 'LF150', 'LF151', 'LF152',
#        'LF153', 'LF154', 'LF155', 'LF156', 'LF157', 'LF158', 'LF159',
#        'LF160', 'LF161', 'LF162', 'LF163', 'LF164', 'LF165', 'LF166',
#        'LF167', 'LF168', 'LF169', 'LF170', 'LF171', 'LF172', 'LF173',
#        'LF174', 'LF175', 'LF176', 'LF177', 'LF178', 'LF179', 'LF180',
#        'LF181', 'LF182', 'LF183', 'LF184', 'LF185', 'LF186', 'LF187',
#        'LF188', 'LF189', 'LF190', 'LF191', 'LF192', 'LF193', 'LF194',
#        'LF195', 'LF196', 'LF197', 'LF198', 'LF199', 'LF200', 'LF201',
#        'LF202', 'LF203', 'LF204', 'LF205', 'LF206', 'LF207', 'LF208',
#        'LF209', 'LF210', 'LF211', 'LF212', 'LF213', 'LF214', 'LF215',
#        'LF216', 'LF217', 'LF218', 'LF219', 'LF220', 'LF221', 'LF222',
#        'LF223', 'LF224', 'LF225', 'LF226', 'LF227', 'LF228', 'LF229',
#        'LF230', 'LF231', 'LF232', 'LF233', 'LF234', 'LF235', 'LF236',
#        'LF237', 'LF238', 'LF239', 'LF240', 'LF241', 'LF242', 'LF243',
#        'LF244', 'LF245', 'LF246', 'LF247', 'LF248', 'LF249', 'LF250',
#        'LF251', 'LF252', 'LF253', 'LF254', 'LF255', 'LF256', 'LF257',
#        'LF258', 'LF259', 'LF260', 'LF261', 'LF262', 'LF263', 'LF264',
#        'LF265', 'LF266', 'LF267', 'LF268', 'LF269', 'LF270', 'LF271',
#        'LF272', 'LF273', 'LF274', 'LF275', 'LF276', 'LF277', 'LF278',
#        'LF279', 'LF280', 'LF281', 'LF282', 'LF283', 'LF284', 'LF285',
#        'LF286', 'LF287', 'LF288', 'LF289', 'LF290', 'LF291', 'LF292',
#        'LF293', 'LF294', 'LF295', 'LF296', 'LF297', 'LF298', 'LF299',
#        'LF300', 'LF301', 'LF302', 'LF303', 'LF304', 'LF305', 'LF306',
#        'LF307', 'LF308', 'LF309', 'LF310', 'LF311', 'LF312', 'LF313',
#        'LF314', 'LF315', 'LF316', 'LF317', 'LF318', 'LF319', 'LF320',
#        'LF321', 'LF322', 'LF323', 'LF324', 'LF325', 'LF326', 'LF327',
#        'LF328', 'LF329', 'LF330', 'LF331', 'LF332', 'LF333', 'LF334',
#        'LF335', 'LF336', 'LF337', 'LF338', 'LF339', 'LF340', 'LF341',
#        'LF342', 'LF343', 'LF344', 'LF345', 'LF346', 'LF347', 'LF348',
#        'LF349', 'LF350', 'LF351', 'LF352', 'LF353', 'LF354', 'LF355',
#        'LF356', 'LF357', 'LF358', 'LF359', 'LF360', 'LF361', 'LF362',
#        'LF363', 'LF364', 'LF365', 'LF366', 'LF367', 'LF368', 'LF369',
#        'LF370', 'LF371', 'LF372', 'LF373', 'LF374', 'LF375', 'LF376',
#        'LF377', 'LF378', 'LF379', 'LF380', 'LF381', 'LF382', 'LF383',
#        'SY0'], dtype=object)

# %%
pd.DataFrame(atp, columns=['name', 'order', 'abs_order'])
# Out:
#       name order abs_order
# 0      LF0   384       384
# 1      LF1   385       385
# 2      LF2   386       386
# 3      LF3   387       387
# 4      LF4   388       388
# 5      LF5   389       389
# 6      LF6   390       390
# 7      LF7   391       391
# 8      LF8   392       392
# 9      LF9   393       393
# 10    LF10   394       394
# 11    LF11   395       395
# 12    LF12   396       396
# 13    LF13   397       397
# 14    LF14   398       398
# 15    LF15   399       399
# 16    LF16   400       400
# 17    LF17   401       401
# 18    LF18   402       402
# 19    LF19   403       403
# 20    LF20   404       404
# 21    LF21   405       405
# 22    LF22   406       406
# 23    LF23   407       407
# 24    LF24   408       408
# 25    LF25   409       409
# 26    LF26   410       410
# 27    LF27   411       411
# 28    LF28   412       412
# 29    LF29   413       413
# ..     ...   ...       ...
# 355  LF355   739       739
# 356  LF356   740       740
# 357  LF357   741       741
# 358  LF358   742       742
# 359  LF359   743       743
# 360  LF360   744       744
# 361  LF361   745       745
# 362  LF362   746       746
# 363  LF363   747       747
# 364  LF364   748       748
# 365  LF365   749       749
# 366  LF366   750       750
# 367  LF367   751       751
# 368  LF368   752       752
# 369  LF369   753       753
# 370  LF370   754       754
# 371  LF371   755       755
# 372  LF372   756       756
# 373  LF373   757       757
# 374  LF374   758       758
# 375  LF375   759       759
# 376  LF376   760       760
# 377  LF377   761       761
# 378  LF378   762       762
# 379  LF379   763       763
# 380  LF380   764       764
# 381  LF381   765       765
# 382  LF382   766       766
# 383  LF383   767       767
# 384    SY0   768       768
#
# [385 rows x 3 columns]

# %%
chans_tuple_list = lf_chans.split(')(')

# %%
chans_tuple_list[-1]=chans_tuple_list[-1].split(')')[0]

# %%
rs = parse.parse('{};{}:{}', chans_tuple_list[-1]).fixed
rs
# Out:
# ('SY0', '768', '768')

# %%
lf_chans = cp.get('root', '~snsChanMap')

# %%
datetime.datetime.strptime(time_str, "%Y-%m-%dT%H:%M:%S")
# Out:
# datetime.datetime(2016, 7, 22, 18, 15, 30)

# %% [markdown]
# #### Update a session with subsequently recorded rhd files

# %%
reload(kwdf)
_, nu_pd, _ = kwdf.update_kwd(kwd_path, raw_folder)
# Out:
# 2019-04-27 00:57:00,740 - pipefinch.h5tools.kwik.kwdfunctions - INFO - updating kwd file /Volumes/Samsung_X5/microdrive/p14r14/Ephys/kwik/2019-02-15_3125_01/streams.kwd from folder /Volumes/Samsung_X5/microdrive/p14r14/Ephys/raw/2019-02-15_3125_01
# 2019-04-27 00:57:00,882 - pipefinch.h5tools.kwik.kwdfunctions - INFO - No new files to add to the file

# %% [markdown]
# ## Make .mda file with a set of recordings in a session
#  - pick all in port A
#  - get all rec within a time range

# %%
# get the session meta
pd_meta = kwdf.get_all_rec_meta(kwd_path)
pd_meta.head()
# Out:
#    bit_depth  name  sample_rate  start_sample          start_time  \
# 0         16     0      20000.0             0 2019-02-15 10:23:23
# 1         16     1      20000.0             0 2019-02-15 10:27:38
# 2         16     2      20000.0             0 2019-02-15 10:30:28
# 3         16     3      20000.0             0 2019-02-15 10:34:55
# 4         16     4      20000.0             0 2019-02-15 10:37:45
#
#                                    channel_bit_volts  \
# 0  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
# 1  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
# 2  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
# 3  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
# 4  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
#
#                                        channel_names  \
# 0  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
# 1  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
# 2  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
# 3  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
# 4  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
#
#                                 channels_sample_rate dig_channel_names  \
# 0  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
# 1  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
# 2  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
# 3  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
# 4  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
#
#    is_multiSampleRate_data                                      valid_samples  \
# 0                        0  [3484080.0, 3484080.0, 3484080.0, 3484080.0, 3...
# 1                        0  [1997280.0, 1997280.0, 1997280.0, 1997280.0, 1...
# 2                        0  [4657680.0, 4657680.0, 4657680.0, 4657680.0, 4...
# 3                        0  [3566160.0, 3566160.0, 3566160.0, 3566160.0, 3...
# 4                        0  [5299200.0, 5299200.0, 5299200.0, 5299200.0, 5...
#
#    samples_count
# 0        3484080
# 1        1997280
# 2        4657680
# 3        3566160
# 4        5299200

# %% [markdown]
# ### pick a time interval of the recordings

# %%
def select_time_span(meta_pd, start, span_minutes):
    end = start + timedelta(minutes=span_minutes)
    pd_selection = meta_pd.loc[meta_pd['start_time'].between(start, end)]
    return pd_selection

pd_meta_selection = select_time_span(pd_meta, pd_meta['start_time'][0], 240)

# %%
# for instance
pd_meta_selection.head()
# Out:
#    bit_depth  name  sample_rate  start_sample          start_time  \
# 0         16     0      20000.0             0 2019-02-15 10:23:23
# 1         16     1      20000.0             0 2019-02-15 10:27:38
# 2         16     2      20000.0             0 2019-02-15 10:30:28
# 3         16     3      20000.0             0 2019-02-15 10:34:55
# 4         16     4      20000.0             0 2019-02-15 10:37:45
#
#                                    channel_bit_volts  \
# 0  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
# 1  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
# 2  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
# 3  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
# 4  [0.195, 0.195, 0.195, 0.195, 0.195, 0.195, 0.1...
#
#                                        channel_names  \
# 0  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
# 1  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
# 2  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
# 3  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
# 4  [A-000, A-001, A-002, A-003, A-004, A-005, A-0...
#
#                                 channels_sample_rate dig_channel_names  \
# 0  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
# 1  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
# 2  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
# 3  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
# 4  [20000.0, 20000.0, 20000.0, 20000.0, 20000.0, ...  [DIN-00, DIN-01]
#
#    is_multiSampleRate_data                                      valid_samples  \
# 0                        0  [3484080.0, 3484080.0, 3484080.0, 3484080.0, 3...
# 1                        0  [1997280.0, 1997280.0, 1997280.0, 1997280.0, 1...
# 2                        0  [4657680.0, 4657680.0, 4657680.0, 4657680.0, 4...
# 3                        0  [3566160.0, 3566160.0, 3566160.0, 3566160.0, 3...
# 4                        0  [5299200.0, 5299200.0, 5299200.0, 5299200.0, 5...
#
#    samples_count
# 0        3484080
# 1        1997280
# 2        4657680
# 3        3566160
# 4        5299200

# %%
# load the rig parameters
rig_par_file = exp_struct['files']['rig']
with open(rig_par_file, 'r') as fp:
    rig_par = json.load(fp)

# get the probe and the port where the probe was connected
selected_probe = sess_par['probe']
probe_port = rig_par['chan']['port'][selected_probe].strip('-')

# get the channel indices of the probe's port
wanted_chans = np.array([probe_port + '-'])  # all ephys channels

chan_list = kwdf.get_all_chan_names(pd_meta_selection, chan_filt=wanted_chans)

#all_rec_list = kutil.get_rec_list(exp_struct['files']['kwd'])
selection_rec_list = np.unique(pd_meta_selection['name'])

rec_chans = pd_meta.loc[pd_meta['name'] == selection_rec_list[0], 'channel_names'].values
rec_chans_idx = kwdf.find_chan_names_idx(rec_chans[0], chan_list)

# make the mda binary file
bin_path = exp_struct['files']['bin_raw']
os.makedirs(exp_struct['folders']['ksort'], exist_ok=True)
bin_file = kwdf.kwd_to_binary(exp_struct['files']['kwd'],
                              exp_struct['files']['bin_raw'],
                              chan_list=chan_list,
                              rec_list=selection_rec_list, header='bin')
# Out:
# 2019-04-23 15:41:14,472 - pipefinch.h5tools.kwik.kwdfunctions - INFO - Writing kwd_file /Volumes/Samsung_X5/microdrive/p14r14/Ephys/kwik/2019-02-15_3125_01/streams.kwd to binary
# 2019-04-23 15:41:14,492 - pipefinch.h5tools.kwik.kwdfunctions - INFO - Channels to extract: ['A-000' 'A-001' 'A-002' 'A-003' 'A-004' 'A-005' 'A-006' 'A-007' 'A-008'
#  'A-009' 'A-010' 'A-011' 'A-012' 'A-013' 'A-014' 'A-015' 'A-016' 'A-017'
#  'A-018' 'A-019' 'A-020' 'A-021' 'A-022' 'A-023' 'A-024' 'A-025' 'A-026'
#  'A-027' 'A-028' 'A-029' 'A-030' 'A-031']
# 2019-04-23 15:41:14,493 - pipefinch.h5tools.kwik.kwdfunctions - INFO - Will go through recs [0 1 2 3 4]
# 2019-04-23 15:41:14,494 - pipefinch.h5tools.kwik.kwdfunctions - INFO - Creating binary file /Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/raw.bin
# HBox(children=(IntProgress(value=0, description='raw.bin', max=5, style=ProgressStyle(description_width='initi…
# 2019-04-23 15:41:25,382 - pipefinch.h5tools.kwik.kwdfunctions - INFO - 608140800 elements written

# %% [markdown]
# ## Scripts for sorting with Kilosort
# Steps involved:
#  - Make binary file with selected recs, chans
#  - Set kilosort parameters
#  - Make kilosort chanmap
#  - Make kilosort scripts and phy parameters file (for manual curation)
#  - Run the kilosort scripts (via matlab)
#  - Expose the paths for manual curation
#  - After curation, make the kwik file with sorted data
#  - Cleanup and move metadata to permanentt locations

# %% [markdown]
# ### prep the files with their nice formats, locations and names

# %%
from pipefinch.neural.sort.kilo import core as ksc

# %%
reload(ksc)
ks_params = {'use_gpu': 1,
            'auto_merge': 1,
            'filt_per_chan': 4,
            's_f': 30000,
            'n_chan': 32}

# %%
reload(kwdf)
# Out:
# <module 'pipefinch.h5tools.kwik.kwdfunctions' from '/Users/zeke/repos/pipefinch/pipefinch/h5tools/kwik/kwdfunctions.py'>

# %%
kwdf.get_data_type(exp_struct['files']['kwd'])
# Out:
# dtype('int16')

# %%
exp_struct['folders']['ksort']
# Out:
# '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01'

# %%
reload(ksc)
reload(probes)
file_paths, out_folder = ksc.make_paths(exp_struct['folders']['ksort'])
#os.makedirs(exp_struct['folders']['msort'], exist_ok=True)

# make the probe file
rec_chans = pd_meta.loc[pd_meta['name']==0, 'channel_names'].values
rec_chans_idx = kwdf.find_chan_names_idx(rec_chans[0], chan_list)
probe = rig_par['probe'][selected_probe]['model']
headstage = rig_par['probe'][selected_probe]['headstage']
probe_chans = rec_chans_idx - np.min(rec_chans_idx)

probe_dict = probes.make_map(probe, probe_chans, return_dict=True)
kilo_chan_map = ksc.make_kilo_chanmap(probe_dict, file_paths['prb'])

# parameters to pass to the msort scripts, other than de defaults
ks_params.update({'s_f': int(kwdf.get_sampling_rate(pd_meta, 0)), # required,
                  'n_chan': probe_chans.size, # total number of chans in the .bin file,
                  'dtype_name': kwdf.get_data_type(exp_struct['files']['kwd']).name
            })
ksc.make_kilo_scripts(exp_struct['folders']['ksort'], ks_params)
phy_pars = ksc.make_phy_par_file(ks_params, file_paths)
# Out:
# 2019-04-23 17:23:31,702 - pipefinch.neural.sort.kilo.core - INFO - Written kilo script /Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/master.m
# 2019-04-23 17:23:31,706 - pipefinch.neural.sort.kilo.core - INFO - Written kilo script /Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/config.m
# 2019-04-23 17:23:31,709 - pipefinch.neural.sort.kilo.core - INFO - Written phy parameters file /Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/params.py

# %%
file_paths
# Out:
# {'bin': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/raw.bin',
#  'params': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/params.json',
#  'prb': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/chanMap.mat',
#  'rez': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/rez2.mat',
#  'mat_log': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/kilosort_mat.log',
#  'phy_par': '/Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/params.py'}

# %%
reload(ksc)
ksc.do_the_sort(file_paths)
# Out:
# 2019-04-23 17:34:50,661 - pipefinch.neural.sort.kilo.core - INFO - Running kilosort on matlab
# 2019-04-23 17:34:50,661 - pipefinch.neural.sort.kilo.core - INFO - Sort folder is /Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01
# 2019-04-23 17:34:50,662 - pipefinch.neural.sort.kilo.core - INFO - output to /Volumes/Samsung_X5/scratch/p14r14/Ephys/ksort/2019-02-15_3125_01/kilosort_mat.log
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-a5d7696b68a2> in <module>()
#       1 reload(ksc)
# ----> 2 ksc.do_the_sort(file_paths)
#
# ~/repos/pipefinch/pipefinch/neural/sort/kilo/core.py in do_the_sort(kilo_paths)
#      98     # pause the module logger and log to a different thing.
#      99     logger.disabled = True
# --> 100     sorter = subprocess.check_output(['matlab', '-nodesktop', '-nosplash', '-noawt', mlb_cmd, log_cmd])
#     101     logger.disabled = False
#     102     return sorter
#
# ~/anaconda3/envs/mountain/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     354
#     355     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 356                **kwargs).stdout
#     357
#     358
#
# ~/anaconda3/envs/mountain/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     421         kwargs['stdin'] = PIPE
#     422
# --> 423     with Popen(*popenargs, **kwargs) as process:
#     424         try:
#     425             stdout, stderr = process.communicate(input, timeout=timeout)
#
# ~/anaconda3/envs/mountain/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     727                                 c2pread, c2pwrite,
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#     731             # Cleanup if the child failed starting.
#
# ~/anaconda3/envs/mountain/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1362                         if errno_num == errno.ENOENT:
#    1363                             err_msg += ': ' + repr(err_filename)
# -> 1364                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1365                 raise child_exception_type(err_msg)
#    1366
#
# FileNotFoundError: [Errno 2] No such file or directory: 'matlab': 'matlab'

# %%
output_dir = os.path.join(exp_struct['folders']['msort'], 'sort_out');
# Pipeline was failing, need to debug this ('NameError: name 'widgets' is not defined')
# with Pipeline:
#     msc.sort_dataset(file_paths=file_paths, adjacency_radius=-1, detect_threshold=3, dispatch_method='add')

msc.sort_dataset(file_paths=file_paths, **sort_params);
# Out:
# 2019-02-22 14:59:18,248 - pipefinch.sort.mountain.comre - INFO - Bandpass filter
# RUNNING: ml-run-process ephys.bandpass_filter --inputs timeseries:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/raw.mda --parameters freq_max:6000 freq_min:600 samplerate:20000 --outputs timeseries_out:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/filt.mda.prv
# 2019-02-22 15:03:39,760 - pipefinch.sort.mountain.comre - INFO - Whitening
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: 6fa90314bd60526260e249eaf7c88fb5a53b740e
# [ Checking outputs... ]
# {"timeseries_out":"/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/filt.mda.prv"}
# Processing ouput - /media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/filt.mda.prv
# false
# {"timeseries_out":"/media/zinch/Windows/experiment/msort-tmp/output_6fa90314bd60526260e249eaf7c88fb5a53b740e_timeseries_out.mda"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /media/zinch/Windows/experiment/msort-tmp/output_6fa90314bd60526260e249eaf7c88fb5a53b740e_timeseries_out.mda
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ephys/preprocessing/preprocessing.py.mp ephys.bandpass_filter --_tempdir=/media/zinch/Windows/experiment/msort-tmp/tempdir_6fa90314bd_KCd5fg --timeseries=/media/zinch/Windows/experiment/msort-tmp/tempdir_6fa90314bd_KCd5fg/input_timeseries_pccvG76o.mda --timeseries_out=/media/zinch/Windows/experiment/msort-tmp/tempdir_6fa90314bd_KCd5fg/output_timeseries_out.mda --freq_max=6000 --freq_min=600 --samplerate=20000
# Chunk size: 30000, Padding: 3000, Num chunks: 6718, Num processes: 8
#
# Processed 420 of 6718 chunks...
# Processed 1253 of 6718 chunks...
# Processed 2155 of 6718 chunks...
# Processed 2298 of 6718 chunks...
# Processed 3004 of 6718 chunks...
# Processed 3556 of 6718 chunks...
# Processed 4235 of 6718 chunks...
# Processed 4388 of 6718 chunks...
# Processed 5795 of 6718 chunks...
#
# Processed 282 of 6718 chunks...
# Processed 851 of 6718 chunks...
# Processed 1555 of 6718 chunks...
# Processed 1709 of 6718 chunks...
# Processed 2858 of 6718 chunks...
# Processed 3147 of 6718 chunks...
# Processed 3689 of 6718 chunks...
# Processed 5938 of 6718 chunks...
# Processed 6502 of 6718 chunks...
# Processed 6644 of 6718 chunks...
# Processed 1003 of 6718 chunks...
# Processed 2012 of 6718 chunks...
# Processed 3822 of 6718 chunks...
# Processed 4085 of 6718 chunks...
# Processed 4670 of 6718 chunks...
# Processed 5355 of 6718 chunks...
# Processed 5654 of 6718 chunks...
# Processed 6356 of 6718 chunks...
# Processed 565 of 6718 chunks...
# Processed 709 of 6718 chunks...
# Processed 1862 of 6718 chunks...
# Processed 2422 of 6718 chunks...
# Processed 4923 of 6718 chunks...
# Processed 2568 of 6718 chunks...
# Processed 2711 of 6718 chunks...
# Processed 6062 of 6718 chunks...
# Processed 6213 of 6718 chunks...
# Processed 1399 of 6718 chunks...
# Processed 3961 of 6718 chunks...
# Processed 5204 of 6718 chunks...
# Processed 3280 of 6718 chunks...
# Processed 4810 of 6718 chunks...
# Processed 5504 of 6718 chunks...
# Processed 137 of 6718 chunks...
# Processed 1153 of 6718 chunks...
# Processed 3426 of 6718 chunks...
# Processed 4530 of 6718 chunks...
# Processed 5066 of 6718 chunks...
# Processed 5938 of 6718 chunks...
#
# Elapsed time for processor ephys.bandpass_filter: 191.265 sec
# Finalizing output timeseries_out
# [ Creating output prv for timeseries_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ephys.whiten --inputs timeseries:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/filt.mda.prv --parameters --outputs timeseries_out:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/pre.mda.prv
# 2019-02-22 15:07:38,274 - pipefinch.sort.mountain.comre - INFO - Sorting
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: 40459222a70a1577e2eaf27302d72d93dd553dab
# [ Checking outputs... ]
# {"timeseries_out":"/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/pre.mda.prv"}
# Processing ouput - /media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/pre.mda.prv
# false
# {"timeseries_out":"/media/zinch/Windows/experiment/msort-tmp/output_40459222a70a1577e2eaf27302d72d93dd553dab_timeseries_out.mda"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /media/zinch/Windows/experiment/msort-tmp/output_40459222a70a1577e2eaf27302d72d93dd553dab_timeseries_out.mda
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ephys/preprocessing/preprocessing.py.mp ephys.whiten --_tempdir=/media/zinch/Windows/experiment/msort-tmp/tempdir_40459222a7_BEO86u --timeseries=/media/zinch/Windows/experiment/msort-tmp/tempdir_40459222a7_BEO86u/input_timeseries_g6UEF3wl.mda --timeseries_out=/media/zinch/Windows/experiment/msort-tmp/tempdir_40459222a7_BEO86u/output_timeseries_out.mda
# Chunk size: 300000, Num chunks: 672, Num processes: 8
#
# Processed 24 of 672 chunks...
# Processed 440 of 672 chunks...
#
# Processed 97 of 672 chunks...
# Processed 273 of 672 chunks...
# Processed 353 of 672 chunks...
# Processed 577 of 672 chunks...
# Processed 154 of 672 chunks...
# Processed 218 of 672 chunks...
# Processed 490 of 672 chunks...
# Processed 522 of 672 chunks...
# Processed 650 of 672 chunks...
# Processed 43 of 672 chunks...
# Processed 59 of 672 chunks...
# Processed 459 of 672 chunks...
# Processed 595 of 672 chunks...
# Processed 627 of 672 chunks...
#
# Processed 116 of 672 chunks...
# Processed 172 of 672 chunks...
# Processed 292 of 672 chunks...
# Processed 372 of 672 chunks...
# Processed 668 of 672 chunks...
#
# Processed 189 of 672 chunks...
# Processed 237 of 672 chunks...
# Processed 389 of 672 chunks...
# Processed 477 of 672 chunks...
# Processed 541 of 672 chunks...
# Processed 613 of 672 chunks...
#
# Processed 78 of 672 chunks...
# Processed 254 of 672 chunks...
# Processed 342 of 672 chunks...
# Processed 406 of 672 chunks...
# Processed 422 of 672 chunks...
# Processed 638 of 672 chunks...
#
# Processed 135 of 672 chunks...
# Processed 199 of 672 chunks...
# Processed 311 of 672 chunks...
# Processed 327 of 672 chunks...
# Processed 503 of 672 chunks...
# Processed 559 of 672 chunks...
#
# Elapsed time for processor ephys.whiten: 165.749 sec
# Finalizing output timeseries_out
# [ Creating output prv for timeseries_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms4alg.sort --inputs geom:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/geom.csv timeseries:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/pre.mda.prv --parameters adjacency_radius:-1 detect_sign:-1 detect_threshold:2 --outputs firings_out:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings.mda
# 2019-02-22 16:12:15,210 - pipefinch.sort.mountain.comre - INFO - Getting cluster metrics
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: f6959c75fc9c091d895f7fef9038a9bcea0094bf
# [ Checking outputs... ]
# {"firings_out":"/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings.mda"}
# Processing ouput - /media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings.mda
# false
# {"firings_out":"/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings.mda"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings.mda
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ms4alg/ms4alg_spec.py.mp ms4alg.sort --_tempdir=/media/zinch/Windows/experiment/msort-tmp/tempdir_f6959c75fc_GQoxlG --geom=/media/zinch/Windows/experiment/msort-tmp/tempdir_f6959c75fc_GQoxlG/input_geom_k2jYsXxe.csv --timeseries=/media/zinch/Windows/experiment/msort-tmp/tempdir_f6959c75fc_GQoxlG/input_timeseries_j3BgSY6F.mda --firings_out=/media/zinch/Windows/experiment/msort-tmp/tempdir_f6959c75fc_GQoxlG/output_firings_out.mda --adjacency_radius=-1 --detect_sign=-1 --detect_threshold=2
# Using tempdir=/media/zinch/Windows/experiment/msort-tmp/tempdir_f6959c75fc_GQoxlG
# Preparing /media/zinch/Windows/experiment/msort-tmp/tempdir_f6959c75fc_GQoxlG/timeseries.hdf5...
# Preparing neighborhood sorters (M=32, N=201518640)...
#
# Detecting events on channel 3 (phase1)...
#
# Detecting events on channel 1 (phase1)...
#
# Detecting events on channel 2 (phase1)...
#
# Detecting events on channel 4 (phase1)...
#
# Detecting events on channel 5 (phase1)...
#
# Detecting events on channel 6 (phase1)...
#
# Detecting events on channel 7 (phase1)...
#
# Detecting events on channel 8 (phase1)...
#
# Num events detected on channel 8 (phase1): 3128702
#
# Computing PCA features for channel 8 (phase1)...
#
# Num events detected on channel 3 (phase1): 3146074
#
# Computing PCA features for channel 3 (phase1)...
#
# Num events detected on channel 7 (phase1): 3073809
#
# Computing PCA features for channel 7 (phase1)...
#
# Num events detected on channel 6 (phase1): 3041104
# Computing PCA features for channel 6 (phase1)...
#
# Num events detected on channel 2 (phase1): 3049363
#
# Computing PCA features for channel 2 (phase1)...
#
# Num events detected on channel 5 (phase1): 3214790
#
# Computing PCA features for channel 5 (phase1)...
#
# Num events detected on channel 1 (phase1): 3082088
#
# Num events detected on channel 4 (phase1): 3177234
# Computing PCA features for channel 4 (phase1)...
#
# Computing PCA features for channel 1 (phase1)...
#
# Clustering for channel 6 (phase1)...
#
# Clustering for channel 2 (phase1)...
#
# Clustering for channel 1 (phase1)...
#
# Clustering for channel 7 (phase1)...
#
# Clustering for channel 4 (phase1)...
#
# Clustering for channel 8 (phase1)...
#
# Clustering for channel 3 (phase1)...
#
# Clustering for channel 5 (phase1)...
#
# Found 10 clusters for channel 4 (phase1)...
#
# Computing templates for channel 4 (phase1)...
#
# Found 9 clusters for channel 7 (phase1)...
#
# Computing templates for channel 7 (phase1)...
#
# Found 5 clusters for channel 6 (phase1)...
#
# Computing templates for channel 6 (phase1)...
#
# Found 7 clusters for channel 1 (phase1)...
#
# Computing templates for channel 1 (phase1)...
#
# Found 6 clusters for channel 3 (phase1)...
#
# Computing templates for channel 3 (phase1)...
#
# Found 8 clusters for channel 8 (phase1)...
#
# Computing templates for channel 8 (phase1)...
#
# Found 8 clusters for channel 2 (phase1)...
#
# Computing templates for channel 2 (phase1)...
#
# Found 10 clusters for channel 5 (phase1)...
#
# Computing templates for channel 5 (phase1)...
#
# Re-assigning events for channel 4 (phase1)...
#
# Detecting events on channel 9 (phase1)...
#
# Re-assigning events for channel 7 (phase1)...
#
# Detecting events on channel 10 (phase1)...
#
# Re-assigning events for channel 6 (phase1)...
#
# Re-assigning 1 events from 6 to 31 with dt=-3 (k=2)
#
# Re-assigning 1 events from 6 to 27 with dt=-3 (k=3)
#
# Detecting events on channel 11 (phase1)...
#
# Re-assigning events for channel 1 (phase1)...
#
# Detecting events on channel 12 (phase1)...
#
# Re-assigning events for channel 3 (phase1)...
#
# Detecting events on channel 13 (phase1)...
#
# Re-assigning events for channel 2 (phase1)...
#
# Re-assigning 1 events from 2 to 27 with dt=3 (k=4)
#
# Detecting events on channel 14 (phase1)...
#
# Re-assigning events for channel 8 (phase1)...
#
# Re-assigning 5 events from 8 to 32 with dt=3 (k=1)
#
# Re-assigning 1 events from 8 to 31 with dt=3 (k=4)
#
# Re-assigning 5 events from 8 to 9 with dt=7 (k=6)
#
# Detecting events on channel 15 (phase1)...
#
# Re-assigning events for channel 5 (phase1)...
#
# Re-assigning 1 events from 5 to 31 with dt=5 (k=10)
#
# Detecting events on channel 16 (phase1)...
#
# Num events detected on channel 10 (phase1): 3182716
#
# Computing PCA features for channel 10 (phase1)...
#
# Num events detected on channel 9 (phase1): 3285778
# Computing PCA features for channel 9 (phase1)...
#
# Num events detected on channel 11 (phase1): 3160328
#
# Computing PCA features for channel 11 (phase1)...
#
# Num events detected on channel 12 (phase1): 3233505
#
# Computing PCA features for channel 12 (phase1)...
#
# Num events detected on channel 13 (phase1): 3303672
#
# Computing PCA features for channel 13 (phase1)...
#
# Num events detected on channel 14 (phase1): 3198374
#
# Computing PCA features for channel 14 (phase1)...
#
# Num events detected on channel 15 (phase1): 3141154
#
# Computing PCA features for channel 15 (phase1)...
#
# Num events detected on channel 16 (phase1): 3130781
# Computing PCA features for channel 16 (phase1)...
#
# Clustering for channel 10 (phase1)...
#
# Clustering for channel 11 (phase1)...
#
# Clustering for channel 9 (phase1)...
#
# Clustering for channel 12 (phase1)...
#
# Clustering for channel 13 (phase1)...
#
# Clustering for channel 15 (phase1)...
#
# Clustering for channel 14 (phase1)...
#
# Clustering for channel 16 (phase1)...
#
# Found 9 clusters for channel 9 (phase1)...
#
# Computing templates for channel 9 (phase1)...
#
# Found 7 clusters for channel 11 (phase1)...
#
# Computing templates for channel 11 (phase1)...
#
# Found 6 clusters for channel 10 (phase1)...
#
# Computing templates for channel 10 (phase1)...
#
# Found 9 clusters for channel 12 (phase1)...
#
# Computing templates for channel 12 (phase1)...
#
# Found 10 clusters for channel 14 (phase1)...
#
# Computing templates for channel 14 (phase1)...
#
# Found 11 clusters for channel 16 (phase1)...
# Computing templates for channel 16 (phase1)...
#
# Found 8 clusters for channel 13 (phase1)...
#
# Computing templates for channel 13 (phase1)...
#
# Found 13 clusters for channel 15 (phase1)...
#
# Computing templates for channel 15 (phase1)...
#
# Re-assigning events for channel 10 (phase1)...
#
# Re-assigning 10 events from 10 to 31 with dt=3 (k=1)
#
# Re-assigning 16 events from 10 to 32 with dt=3 (k=3)
#
# Detecting events on channel 17 (phase1)...
#
# Re-assigning events for channel 11 (phase1)...
#
# Re-assigning 1 events from 11 to 32 with dt=3 (k=1)
#
# Re-assigning 1 events from 11 to 27 with dt=3 (k=2)
#
# Re-assigning 1 events from 11 to 31 with dt=3 (k=5)
#
# Detecting events on channel 18 (phase1)...
#
# Re-assigning events for channel 9 (phase1)...
#
# Re-assigning 1 events from 9 to 7 with dt=-7 (k=4)
#
# Re-assigning 2 events from 9 to 7 with dt=-6 (k=5)
#
# Re-assigning 1 events from 9 to 27 with dt=-3 (k=7)
#
# Detecting events on channel 19 (phase1)...
#
# Re-assigning events for channel 12 (phase1)...
#
# Re-assigning 2 events from 12 to 27 with dt=-3 (k=3)
#
# Re-assigning 1 events from 12 to 32 with dt=-3 (k=4)
#
# Detecting events on channel 20 (phase1)...
#
# Re-assigning events for channel 14 (phase1)...
#
# Detecting events on channel 21 (phase1)...
#
# Re-assigning events for channel 16 (phase1)...
#
# Detecting events on channel 22 (phase1)...
#
# Re-assigning events for channel 13 (phase1)...
#
# Re-assigning 1 events from 13 to 4 with dt=3 (k=1)
#
# Re-assigning 1 events from 13 to 31 with dt=-3 (k=8)
#
# Detecting events on channel 23 (phase1)...
#
# Re-assigning events for channel 15 (phase1)...
#
# Detecting events on channel 24 (phase1)...
#
# Num events detected on channel 17 (phase1): 2663918
#
# Computing PCA features for channel 17 (phase1)...
#
# Num events detected on channel 18 (phase1): 3144647
#
# Computing PCA features for channel 18 (phase1)...
#
# Num events detected on channel 19 (phase1): 2978460
#
# Computing PCA features for channel 19 (phase1)...
#
# Num events detected on channel 20 (phase1): 3198282
#
# Computing PCA features for channel 20 (phase1)...
#
# Num events detected on channel 21 (phase1): 3117234
#
# Computing PCA features for channel 21 (phase1)...
#
# Num events detected on channel 22 (phase1): 3312831
#
# Computing PCA features for channel 22 (phase1)...
#
# Num events detected on channel 23 (phase1): 3203934
#
# Computing PCA features for channel 23 (phase1)...
#
# Num events detected on channel 24 (phase1): 3155313
#
# Computing PCA features for channel 24 (phase1)...
#
# Clustering for channel 17 (phase1)...
#
# Clustering for channel 18 (phase1)...
#
# Clustering for channel 19 (phase1)...
#
# Clustering for channel 20 (phase1)...
#
# Clustering for channel 21 (phase1)...
#
# Clustering for channel 22 (phase1)...
#
# Clustering for channel 23 (phase1)...
#
# Clustering for channel 24 (phase1)...
#
# Found 8 clusters for channel 19 (phase1)...
#
# Computing templates for channel 19 (phase1)...
#
# Found 10 clusters for channel 17 (phase1)...
#
# Computing templates for channel 17 (phase1)...
#
# Found 5 clusters for channel 18 (phase1)...
#
# Computing templates for channel 18 (phase1)...
#
# Found 9 clusters for channel 21 (phase1)...
#
# Computing templates for channel 21 (phase1)...
#
# Found 5 clusters for channel 20 (phase1)...
#
# Computing templates for channel 20 (phase1)...
#
# Found 10 clusters for channel 23 (phase1)...
#
# Computing templates for channel 23 (phase1)...
#
# Found 10 clusters for channel 22 (phase1)...
#
# Computing templates for channel 22 (phase1)...
#
# Found 13 clusters for channel 24 (phase1)...
#
# Computing templates for channel 24 (phase1)...
#
# Re-assigning events for channel 17 (phase1)...
#
# Detecting events on channel 25 (phase1)...
#
# Re-assigning events for channel 19 (phase1)...
#
# Detecting events on channel 26 (phase1)...
#
# Re-assigning events for channel 18 (phase1)...
#
# Detecting events on channel 27 (phase1)...
#
# Re-assigning events for channel 20 (phase1)...
#
# Detecting events on channel 28 (phase1)...
#
# Re-assigning events for channel 21 (phase1)...
#
# Re-assigning 5 events from 21 to 32 with dt=-3 (k=3)
#
# Re-assigning 2 events from 21 to 31 with dt=-3 (k=4)
#
# Re-assigning 1 events from 21 to 32 with dt=3 (k=7)
#
# Detecting events on channel 29 (phase1)...
#
# Num events detected on channel 25 (phase1): 3172449
#
# Computing PCA features for channel 25 (phase1)...
#
# Re-assigning events for channel 23 (phase1)...
#
# Re-assigning 3 events from 23 to 27 with dt=-3 (k=10)
#
# Detecting events on channel 30 (phase1)...
#
# Re-assigning events for channel 22 (phase1)...
#
# Re-assigning 2 events from 22 to 31 with dt=3 (k=3)
#
# Re-assigning 1 events from 22 to 7 with dt=-3 (k=7)
#
# Detecting events on channel 31 (phase1)...
#
# Re-assigning events for channel 24 (phase1)...
#
# Re-assigning 1 events from 24 to 32 with dt=-21 (k=9)
#
# Detecting events on channel 32 (phase1)...
#
# Num events detected on channel 26 (phase1): 3049007
#
# Computing PCA features for channel 26 (phase1)...
#
# Num events detected on channel 27 (phase1): 3117957
#
# Computing PCA features for channel 27 (phase1)...
#
# Num events detected on channel 28 (phase1): 3100454
#
# Computing PCA features for channel 28 (phase1)...
#
# Num events detected on channel 29 (phase1): 3217757
#
# Computing PCA features for channel 29 (phase1)...
#
# Num events detected on channel 30 (phase1): 3137965
#
# Computing PCA features for channel 30 (phase1)...
#
# Num events detected on channel 32 (phase1): 2408503
#
# Computing PCA features for channel 32 (phase1)...
#
# Num events detected on channel 31 (phase1): 2976025
#
# Computing PCA features for channel 31 (phase1)...
#
# Clustering for channel 25 (phase1)...
#
# Clustering for channel 26 (phase1)...
#
# Clustering for channel 27 (phase1)...
#
# Clustering for channel 28 (phase1)...
#
# Clustering for channel 29 (phase1)...
#
# Clustering for channel 32 (phase1)...
#
# Clustering for channel 31 (phase1)...
#
# Clustering for channel 30 (phase1)...
#
# Found 7 clusters for channel 25 (phase1)...
#
# Computing templates for channel 25 (phase1)...
#
# Found 11 clusters for channel 26 (phase1)...
#
# Computing templates for channel 26 (phase1)...
#
# Found 12 clusters for channel 27 (phase1)...
#
# Computing templates for channel 27 (phase1)...
#
# Found 12 clusters for channel 32 (phase1)...
#
# Computing templates for channel 32 (phase1)...
#
# Found 15 clusters for channel 28 (phase1)...
#
# Computing templates for channel 28 (phase1)...
#
# Found 10 clusters for channel 29 (phase1)...
#
# Computing templates for channel 29 (phase1)...
#
# Found 9 clusters for channel 30 (phase1)...
#
# Computing templates for channel 30 (phase1)...
#
# Found 14 clusters for channel 31 (phase1)...
#
# Computing templates for channel 31 (phase1)...
#
# Re-assigning events for channel 25 (phase1)...
#
# Re-assigning 3 events from 25 to 31 with dt=3 (k=3)
#
# Re-assigning 2 events from 25 to 32 with dt=6 (k=4)
#
# Re-assigning 1 events from 25 to 27 with dt=-3 (k=7)
#
# Re-assigning events for channel 27 (phase1)...
#
# Re-assigning events for channel 26 (phase1)...
#
# Re-assigning 1 events from 26 to 31 with dt=30 (k=2)
#
# Re-assigning 3 events from 26 to 31 with dt=42 (k=7)
#
# Re-assigning 7 events from 26 to 31 with dt=-3 (k=8)
#
# Re-assigning 15 events from 26 to 27 with dt=-3 (k=11)
#
# Re-assigning events for channel 32 (phase1)...
#
# Re-assigning 1 events from 32 to 27 with dt=-3 (k=6)
#
# Re-assigning 5 events from 32 to 31 with dt=-36 (k=9)
#
# Re-assigning events for channel 28 (phase1)...
#
# Re-assigning 3 events from 28 to 27 with dt=3 (k=5)
#
# Re-assigning 5 events from 28 to 31 with dt=3 (k=6)
#
# Re-assigning 1 events from 28 to 31 with dt=13 (k=8)
#
# Re-assigning 1 events from 28 to 27 with dt=-3 (k=15)
#
# Re-assigning events for channel 29 (phase1)...
#
# Re-assigning 1 events from 29 to 32 with dt=3 (k=1)
#
# Re-assigning 1 events from 29 to 31 with dt=3 (k=5)
#
# Re-assigning 2 events from 29 to 27 with dt=-21 (k=6)
#
# Re-assigning 1 events from 29 to 9 with dt=-11 (k=8)
#
# Re-assigning events for channel 31 (phase1)...
#
# Re-assigning 2 events from 31 to 32 with dt=3 (k=2)
#
# Re-assigning 5 events from 31 to 27 with dt=-3 (k=11)
#
# Re-assigning events for channel 30 (phase1)...
#
# Re-assigning 1 events from 30 to 32 with dt=3 (k=6)
#
# Computing PCA features for channel 4 (phase2)...
#
# Computing PCA features for channel 6 (phase2)...
#
# Computing PCA features for channel 3 (phase2)...
#
# Computing PCA features for channel 5 (phase2)...
#
# Computing PCA features for channel 2 (phase2)...
#
# Computing PCA features for channel 1 (phase2)...
#
# Computing PCA features for channel 7 (phase2)...
#
# Computing PCA features for channel 8 (phase2)...
#
# Clustering for channel 6 (phase2)...
#
# Clustering for channel 7 (phase2)...
#
# Clustering for channel 3 (phase2)...
#
# Clustering for channel 5 (phase2)...
#
# Clustering for channel 8 (phase2)...
#
# Clustering for channel 2 (phase2)...
#
# Clustering for channel 4 (phase2)...
#
# Clustering for channel 1 (phase2)...
#
# Found 1 clusters for channel 6 (phase2)...
#
# Computing PCA features for channel 9 (phase2)...
#
# Found 1 clusters for channel 7 (phase2)...
#
# Computing PCA features for channel 10 (phase2)...
#
# Found 1 clusters for channel 8 (phase2)...
#
# Found 1 clusters for channel 2 (phase2)...
#
# Computing PCA features for channel 11 (phase2)...
#
# Computing PCA features for channel 12 (phase2)...
#
# Found 1 clusters for channel 5 (phase2)...
#
# Computing PCA features for channel 13 (phase2)...
#
# Found 1 clusters for channel 1 (phase2)...
#
# Found 1 clusters for channel 3 (phase2)...
#
# Computing PCA features for channel 14 (phase2)...
#
# Computing PCA features for channel 15 (phase2)...
#
# Found 5 clusters for channel 4 (phase2)...
#
# Computing PCA features for channel 16 (phase2)...
#
# Clustering for channel 9 (phase2)...
#
# Clustering for channel 10 (phase2)...
#
# Clustering for channel 12 (phase2)...
#
# Clustering for channel 11 (phase2)...
#
# Clustering for channel 14 (phase2)...
#
# Clustering for channel 15 (phase2)...
#
# Found 1 clusters for channel 10 (phase2)...
#
# Computing PCA features for channel 17 (phase2)...
#
# Found 1 clusters for channel 9 (phase2)...
#
# Computing PCA features for channel 18 (phase2)...
#
# Found 1 clusters for channel 15 (phase2)...
#
# Computing PCA features for channel 19 (phase2)...
#
# Found 1 clusters for channel 11 (phase2)...
#
# Computing PCA features for channel 20 (phase2)...
#
# Found 1 clusters for channel 14 (phase2)...
#
# Computing PCA features for channel 21 (phase2)...
#
# Found 1 clusters for channel 12 (phase2)...
#
# Computing PCA features for channel 22 (phase2)...
#
# Clustering for channel 16 (phase2)...
#
# Clustering for channel 13 (phase2)...
#
# Found 1 clusters for channel 16 (phase2)...
#
# Computing PCA features for channel 23 (phase2)...
#
# Found 1 clusters for channel 13 (phase2)...
#
# Computing PCA features for channel 24 (phase2)...
#
# Clustering for channel 17 (phase2)...
#
# Clustering for channel 20 (phase2)...
#
# Clustering for channel 22 (phase2)...
#
# Clustering for channel 18 (phase2)...
#
# Found 1 clusters for channel 20 (phase2)...
#
# Computing PCA features for channel 25 (phase2)...
#
# Found 1 clusters for channel 17 (phase2)...
#
# Computing PCA features for channel 26 (phase2)...
#
# Clustering for channel 24 (phase2)...
#
# Clustering for channel 23 (phase2)...
#
# Found 1 clusters for channel 22 (phase2)...
#
# Computing PCA features for channel 27 (phase2)...
#
# Found 1 clusters for channel 18 (phase2)...
#
# Computing PCA features for channel 28 (phase2)...
#
# Clustering for channel 19 (phase2)...
#
# Clustering for channel 21 (phase2)...
#
# Found 1 clusters for channel 23 (phase2)...
#
# Computing PCA features for channel 29 (phase2)...
#
# Found 1 clusters for channel 24 (phase2)...
#
# Computing PCA features for channel 30 (phase2)...
#
# Found 1 clusters for channel 19 (phase2)...
#
# Computing PCA features for channel 31 (phase2)...
#
# Found 1 clusters for channel 21 (phase2)...
#
# Computing PCA features for channel 32 (phase2)...
#
# Clustering for channel 26 (phase2)...
#
# Clustering for channel 25 (phase2)...
#
# Found 1 clusters for channel 26 (phase2)...
#
# Found 1 clusters for channel 25 (phase2)...
#
# Clustering for channel 27 (phase2)...
#
# Clustering for channel 28 (phase2)...
#
# Clustering for channel 32 (phase2)...
#
# Clustering for channel 30 (phase2)...
#
# Found 1 clusters for channel 28 (phase2)...
#
# Clustering for channel 29 (phase2)...
#
# Clustering for channel 31 (phase2)...
#
# Found 1 clusters for channel 30 (phase2)...
#
# Found 5 clusters for channel 32 (phase2)...
#
# Found 1 clusters for channel 29 (phase2)...
#
# Found 8 clusters for channel 27 (phase2)...
#
# Found 8 clusters for channel 31 (phase2)...
#
# Preparing output...
#
# Writing firings file...
#
# Done.
#
# Elapsed time for processor ms4alg.sort: 3838.744 sec
# Finalizing output firings_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.cluster_metrics --inputs firings:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings.mda timeseries:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/pre.mda.prv --parameters samplerate:20000 --outputs cluster_metrics_out:/media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_cluster_metrics_out_fe3f39688cb5e014301f1fe124399d55d08fe259.prv
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: 425cd0bfb74ebe10b9e0043775d053714d1b4116
# [ Checking outputs... ]
# {"cluster_metrics_out":"/media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_cluster_metrics_out_fe3f39688cb5e014301f1fe124399d55d08fe259.prv"}
# Processing ouput - /media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_cluster_metrics_out_fe3f39688cb5e014301f1fe124399d55d08fe259.prv
# false
# {"cluster_metrics_out":"/media/zinch/Windows/experiment/msort-tmp/output_425cd0bfb74ebe10b9e0043775d053714d1b4116_cluster_metrics_out.output_cluster_metrics_out_fe3f39688cb5e014301f1fe124399d55d08fe259"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /media/zinch/Windows/experiment/msort-tmp/output_425cd0bfb74ebe10b9e0043775d053714d1b4116_cluster_metrics_out.output_cluster_metrics_out_fe3f39688cb5e014301f1fe124399d55d08fe259
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/etc/mountainlab/packages/ms3.mp ms3.cluster_metrics --_tempdir=/media/zinch/Windows/experiment/msort-tmp/tempdir_425cd0bfb7_ec6msX --firings=/media/zinch/Windows/experiment/msort-tmp/tempdir_425cd0bfb7_ec6msX/input_firings_ZHJu0oGs.mda --timeseries=/media/zinch/Windows/experiment/msort-tmp/tempdir_425cd0bfb7_ec6msX/input_timeseries_stCLRcxD.mda --cluster_metrics_out=/media/zinch/Windows/experiment/msort-tmp/tempdir_425cd0bfb7_ec6msX/output_cluster_metrics_out.output_cluster_metrics_out_fe3f39688cb5e014301f1fe124399d55d08fe259 --samplerate=20000
# Elapsed time for processor ms3.cluster_metrics: 1.044 sec
# Finalizing output cluster_metrics_out
# [ Creating output prv for cluster_metrics_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.isolation_metrics --inputs firings:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings.mda timeseries:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/pre.mda.prv --parameters compute_bursting_parents:true --outputs metrics_out:/media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_metrics_out_8afe7e3a2da74a93f738b8d2d9c68736cfa4db4a.prv
# [ Getting processor spec... ]
# Starting p_isolation_metrics
# [ Checking inputs and substituting prvs ... ]
#
# [ Computing process signature ... ]
# Computing cluster metrics...
# Process signature: f768408ef09b84b45db1ec50a71f39d47f98d6d2
#
# [ Checking outputs... ]
# Computing templates...
# {"metrics_out":"/media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_metrics_out_8afe7e3a2da74a93f738b8d2d9c68736cfa4db4a.prv"}
#
# Processing ouput - /media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_metrics_out_8afe7e3a2da74a93f738b8d2d9c68736cfa4db4a.prv
# Determining pairs to compare...
# false
#
# {"metrics_out":"/media/zinch/Windows/experiment/msort-tmp/output_f768408ef09b84b45db1ec50a71f39d47f98d6d2_metrics_out.output_metrics_out_8afe7e3a2da74a93f738b8d2d9c68736cfa4db4a"}
# Computing bursting parents...
# [ Checking process cache ... ]
#
# [ Creating temporary directory ... ]
# preparing clusters array
# [ Creating links to input files... ]
#
# [ Preparing temporary outputs... ]
# Writing output...
# Processing ouput - /media/zinch/Windows/experiment/msort-tmp/output_f768408ef09b84b45db1ec50a71f39d47f98d6d2_metrics_out.output_metrics_out_8afe7e3a2da74a93f738b8d2d9c68736cfa4db4a
#
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/etc/mountainlab/packages/ms3.mp ms3.isolation_metrics --_tempdir=/media/zinch/Windows/experiment/msort-tmp/tempdir_f768408ef0_zNaLA3 --firings=/media/zinch/Windows/experiment/msort-tmp/tempdir_f768408ef0_zNaLA3/input_firings_lg5cb5Lj.mda --timeseries=/media/zinch/Windows/experiment/msort-tmp/tempdir_f768408ef0_zNaLA3/input_timeseries_lcoA1Dzh.mda --metrics_out=/media/zinch/Windows/experiment/msort-tmp/tempdir_f768408ef0_zNaLA3/output_metrics_out.output_metrics_out_8afe7e3a2da74a93f738b8d2d9c68736cfa4db4a --pair_metrics_out= --compute_bursting_parents=true
# Elapsed time for processor ms3.isolation_metrics: 598.996 sec
# Finalizing output metrics_out
# [ Creating output prv for metrics_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.combine_cluster_metrics --inputs metrics_list:/media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_cluster_metrics_out_fe3f39688cb5e014301f1fe124399d55d08fe259.prv metrics_list:/media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_metrics_out_8afe7e3a2da74a93f738b8d2d9c68736cfa4db4a.prv --parameters --outputs metrics_out:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/cluster_metrics.json
# 2019-02-22 16:24:33,679 - pipefinch.sort.mountain.comre - INFO - Automatically curating
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: a90d63ef1d16bb5d7c873cc75bc766b7e35dee0d
# [ Checking outputs... ]
# {"metrics_out":"/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/cluster_metrics.json"}
# Processing ouput - /media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/cluster_metrics.json
# false
# {"metrics_out":"/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/cluster_metrics.json"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/cluster_metrics.json
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/etc/mountainlab/packages/ms3.mp ms3.combine_cluster_metrics --_tempdir=/media/zinch/Windows/experiment/msort-tmp/tempdir_a90d63ef1d_a7ku7a --metrics_list=/media/zinch/Windows/experiment/msort-tmp/tempdir_a90d63ef1d_a7ku7a/input_metrics_list-0_BnaDcYmP.output_cluster_metrics_out_fe3f39688cb5e014301f1fe124399d55d08fe259 --metrics_list=/media/zinch/Windows/experiment/msort-tmp/tempdir_a90d63ef1d_a7ku7a/input_metrics_list-1_AHQAYFMt.output_metrics_out_8afe7e3a2da74a93f738b8d2d9c68736cfa4db4a --metrics_out=/media/zinch/Windows/experiment/msort-tmp/tempdir_a90d63ef1d_a7ku7a/output_metrics_out.json
# Elapsed time for processor ms3.combine_cluster_metrics: 0.01 sec
# Finalizing output metrics_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms4alg.create_label_map --inputs metrics:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/cluster_metrics.json --parameters --outputs label_map_out:/media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_label_map_out_fbe93c0a11bd6910bb4954e201e39cc8de6c5bcd.prv
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: f705f0bf031ba6bc23ad0b7bc434fe876a6a8b89
# [ Checking outputs... ]
# {"label_map_out":"/media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_label_map_out_fbe93c0a11bd6910bb4954e201e39cc8de6c5bcd.prv"}
# Processing ouput - /media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_label_map_out_fbe93c0a11bd6910bb4954e201e39cc8de6c5bcd.prv
# false
# {"label_map_out":"/media/zinch/Windows/experiment/msort-tmp/output_f705f0bf031ba6bc23ad0b7bc434fe876a6a8b89_label_map_out.output_label_map_out_fbe93c0a11bd6910bb4954e201e39cc8de6c5bcd"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /media/zinch/Windows/experiment/msort-tmp/output_f705f0bf031ba6bc23ad0b7bc434fe876a6a8b89_label_map_out.output_label_map_out_fbe93c0a11bd6910bb4954e201e39cc8de6c5bcd
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ms4alg/curation_spec.py.mp ms4alg.create_label_map --_tempdir=/media/zinch/Windows/experiment/msort-tmp/tempdir_f705f0bf03_NxeazV --metrics=/media/zinch/Windows/experiment/msort-tmp/tempdir_f705f0bf03_NxeazV/input_metrics_EtHTj7QV.json --label_map_out=/media/zinch/Windows/experiment/msort-tmp/tempdir_f705f0bf03_NxeazV/output_label_map_out.output_label_map_out_fbe93c0a11bd6910bb4954e201e39cc8de6c5bcd
# Elapsed time for processor ms4alg.create_label_map: 0.241 sec
# Finalizing output label_map_out
# [ Creating output prv for label_map_out ... ]
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms4alg.apply_label_map --inputs firings:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings.mda label_map:/media/zinch/Windows/experiment/msort-tmp/mountainlab/tmp_short_term/output_label_map_out_fbe93c0a11bd6910bb4954e201e39cc8de6c5bcd.prv --parameters --outputs firings_out:/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings_curated.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# Process signature: 9485275b93a3ade4f4ddc9e4d9cffa181cd8de6d
# [ Checking outputs... ]
# {"firings_out":"/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings_curated.mda"}
# Processing ouput - /media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings_curated.mda
# false
# {"firings_out":"/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings_curated.mda"}
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Creating links to input files... ]
# [ Preparing temporary outputs... ]
# Processing ouput - /media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings_curated.mda
# false
# [ Initializing process ... ]
# [ Running ... ] /home/zinch/conda/envs/msort/bin/python3 /home/zinch/conda/envs/msort/etc/mountainlab/packages/ml_ms4alg/curation_spec.py.mp ms4alg.apply_label_map --_tempdir=/media/zinch/Windows/experiment/msort-tmp/tempdir_9485275b93_MzdAUM --firings=/media/zinch/Windows/experiment/msort-tmp/tempdir_9485275b93_MzdAUM/input_firings_qiql1RHp.mda --label_map=/media/zinch/Windows/experiment/msort-tmp/tempdir_9485275b93_MzdAUM/input_label_map_aiYWW6jN.output_label_map_out_fbe93c0a11bd6910bb4954e201e39cc8de6c5bcd --firings_out=/media/zinch/Windows/experiment/msort-tmp/tempdir_9485275b93_MzdAUM/output_firings_out.mda
# Elapsed time for processor ms4alg.apply_label_map: 1.765 sec
# Finalizing output firings_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]

# %%
file_paths
# Out:
# {'mda': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/raw.mda',
#  'params': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/params.json',
#  'geom': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/geom.csv',
#  'filt': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/filt.mda.prv',
#  'pre': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/pre.mda.prv',
#  'firings': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings.mda',
#  'firings_curated': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings_curated.mda',
#  'cluster_metrics': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/cluster_metrics.json',
#  'cluster_metrics_curated': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/cluster_metrics_curated.json'}

# %% [markdown]
# ## Command for viewing:
#  - open up terminal with the environment msort
#  - go go the ss_data folder for the session
#  - run the command: qt-mountainview --raw raw.mda --filt sort_out/filt.mda.prv --pre sort_out/pre.mda.prv --samplerate=20000 --firings sort_out/firings.mda --cluster_metrics sort_out/cluster_metrics.json

# %% [markdown]
# # After manual curation
#  - save the curated spikes in the sort_out/firings_curated.mda
#  - come back to the notebook and run

# %%
from pipefinch.h5tools.kwik import kwikfunctions as kwkf
reload(kwkf)
reload(et)
firings_to_save = 'firings_curated' # 'curated' or 'firings' for default_output


metrics_to_save = 'cluster_metrics_curated' if firings_to_save == 'firings_curated' else 'cluster_metrics'
kwkf.mda_to_kwik(exp_struct['files']['kwd'],
                 exp_struct['files']['kwik'],
                 file_paths[firings_to_save],
                file_paths[metrics_to_save])
# Out:
# 2019-02-22 17:45:07,691 - pipefinch.h5tools.kwik.kwikfunctions - INFO - Creating kwik file /media/zinch/Windows/experiment/p14r14/ephys/kwik/2019-02-15_3125_0102/spikes.kwik from firings /media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-15_3125_0102/sort_out/firings_curated.mda

# %%
### extract all unit waveforms
from pipefinch.neural import units
units.get_all_unit_waveforms(exp_struct['files']['kwik'], exp_struct['files']['kwd'])
# Out:
# 2019-02-22 17:45:12,635 - pipefinch.neural.units - INFO - About to get all waveforms for 54 units in file /media/zinch/Windows/experiment/p14r14/ephys/kwik/2019-02-15_3125_0102/spikes.kwik
# HBox(children=(IntProgress(value=0, max=54), HTML(value='')))
# 0

# %%
def msort_cleanup(exp_struct: dict):
    # remove the mda files and try to cleanup the msort temp location
    mda_raw_path = exp_struct['files']['mda_raw']
    logger.info('removing intermediate msort mda file {}'.format(mda_raw_path))
    os.remove(mda_raw_path)

def msort_tmp_clean():
    tmp_dir = os.path.abspath(os.environ['ML_TEMPORARY_DIRECTORY'])
    logger.info('Cleaning up msort temp dir {}'.format(tmp_dir))
    
#msort_tmp_clean()
msort_cleanup(exp_struct)

# %%
 exp_struct['files']
# Out:
# {'par': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-13_1750_01/params.json',
#  'set': '/mnt/zuperfinchjr/Data/p14r14/ephys/raw/2019-02-13_1750_01/settings.isf',
#  'kwd': '/media/zinch/Windows/experiment/p14r14/ephys/kwik/2019-02-13_1750_01/streams.kwd',
#  'kwik': '/media/zinch/Windows/experiment/p14r14/ephys/kwik/2019-02-13_1750_01/spikes.kwik',
#  'kwe': '/media/zinch/Windows/experiment/p14r14/ephys/kwik/2019-02-13_1750_01/events.kwe',
#  'mda_raw': '/media/zinch/Windows/experiment/p14r14/ephys/msort/2019-02-13_1750_01/raw.mda'}
